# %%
import pandas as pd
import json
import glob

# %%
with open("problem.json","rb") as f:
    a = json.loads(f.read())

# %%
glob.glob('*')
# Out:
# ['Problem_ex.ipynb',
#  'hacker_problem.json',
#  '소공개_진단모의고사 분류 및 기준 - 최종.csv',
#  '외부 문제 분류 - 백준.csv',
#  'hackerrank.csv',
#  'problem.json',
#  '외부 문제 분류 - 해커랭크.csv']

# %%
df_hacker = pd.read_csv('hackerrank.csv')

# %%
df_hr = pd.read_csv('외부 문제 분류 - 해커랭크.csv')
df_bj = pd.read_csv('외부 문제 분류 - 백준.csv',skiprows=1)
df_cate = pd.read_csv('소공개_진단모의고사 분류 및 기준 - 최종.csv')

# %%
df_cate.fillna(method='ffill', inplace=True)

# %%
df_hr
# Out:
#                                                    URL  \
# 0    https://www.hackerrank.com/challenges/py-hello...
# 1     https://www.hackerrank.com/challenges/py-if-else
# 2    https://www.hackerrank.com/challenges/python-a...
# 3    https://www.hackerrank.com/challenges/python-d...
# 4    https://www.hackerrank.com/challenges/python-l...
# 5    https://www.hackerrank.com/challenges/write-a-...
# 6    https://www.hackerrank.com/challenges/python-p...
# 7    https://www.hackerrank.com/challenges/list-com...
# 8    https://www.hackerrank.com/challenges/find-sec...
# 9    https://www.hackerrank.com/challenges/nested-list
# 10   https://www.hackerrank.com/challenges/finding-...
# 11   https://www.hackerrank.com/challenges/python-l...
# 12   https://www.hackerrank.com/challenges/python-t...
# 13     https://www.hackerrank.com/challenges/swap-case
# 14   https://www.hackerrank.com/challenges/python-s...
# 15   https://www.hackerrank.com/challenges/whats-yo...
# 16   https://www.hackerrank.com/challenges/python-m...
# 17   https://www.hackerrank.com/challenges/find-a-s...
# 18   https://www.hackerrank.com/challenges/string-v...
# 19   https://www.hackerrank.com/challenges/text-ali...
# 20     https://www.hackerrank.com/challenges/text-wrap
# 21   https://www.hackerrank.com/challenges/designer...
# 22   https://www.hackerrank.com/challenges/python-s...
# 23   https://www.hackerrank.com/challenges/alphabet...
# 24    https://www.hackerrank.com/challenges/capitalize
# 25   https://www.hackerrank.com/challenges/the-mini...
# 26   https://www.hackerrank.com/challenges/merge-th...
# 27   https://www.hackerrank.com/challenges/itertool...
# 28   https://www.hackerrank.com/challenges/collecti...
# 29   https://www.hackerrank.com/challenges/itertool...
# ..                                                 ...
# 85   https://www.hackerrank.com/challenges/validati...
# 86   https://www.hackerrank.com/challenges/hex-colo...
# 87   https://www.hackerrank.com/challenges/html-par...
# 88   https://www.hackerrank.com/challenges/html-par...
# 89   https://www.hackerrank.com/challenges/detect-h...
# 90   https://www.hackerrank.com/challenges/xml-1-fi...
# 91   https://www.hackerrank.com/challenges/validati...
# 92   https://www.hackerrank.com/challenges/validati...
# 93   https://www.hackerrank.com/challenges/xml2-fin...
# 94   https://www.hackerrank.com/challenges/standard...
# 95   https://www.hackerrank.com/challenges/validati...
# 96   https://www.hackerrank.com/challenges/decorato...
# 97   https://www.hackerrank.com/challenges/matrix-s...
# 98   https://www.hackerrank.com/challenges/words-score
# 99     https://www.hackerrank.com/challenges/np-arrays
# 100  https://www.hackerrank.com/challenges/np-shape...
# 101  https://www.hackerrank.com/challenges/default-...
# 102  https://www.hackerrank.com/challenges/np-trans...
# 103  https://www.hackerrank.com/challenges/np-conca...
# 104  https://www.hackerrank.com/challenges/np-zeros...
# 105  https://www.hackerrank.com/challenges/np-eye-a...
# 106  https://www.hackerrank.com/challenges/np-array...
# 107  https://www.hackerrank.com/challenges/floor-ce...
# 108  https://www.hackerrank.com/challenges/np-sum-a...
# 109  https://www.hackerrank.com/challenges/np-min-a...
# 110  https://www.hackerrank.com/challenges/np-mean-...
# 111  https://www.hackerrank.com/challenges/np-dot-a...
# 112  https://www.hackerrank.com/challenges/np-inner...
# 113  https://www.hackerrank.com/challenges/np-polyn...
# 114  https://www.hackerrank.com/challenges/np-linea...
#
#                                                   문제제목       정답률  \
# 0                      Say "Hello, World!" With Python  0.974628
# 1                                       Python If-Else  0.912253
# 2                                 Arithmetic Operators  0.986746
# 3                                     Python: Division  0.987764
# 4                                                Loops  0.984220
# 5                                     Write a function  0.902642
# 6                                       Print Function  0.958743
# 7                                  List Comprehensions  0.984657
# 8                            Find the Runner-Up Score!  0.939112
# 9                                         Nested Lists  0.898807
# 10                              Finding the percentage  0.971267
# 11                                               Lists  0.895305
# 12                                              Tuples  0.981736
# 13                                           sWAP cASE  0.985278
# 14                               String Split and Join  0.987638
# 15                                   What's Your Name?  0.979498
# 16                                           Mutations  0.981810
# 17                                       Find a string  0.936213
# 18                                   String Validators  0.938186
# 19                                      Text Alignment  0.981402
# 20                                           Text Wrap  0.988032
# 21                                   Designer Door Mat  0.982432
# 22                                   String Formatting  0.915458
# 23                                    Alphabet Rangoli  0.973757
# 24                                         Capitalize!  0.821237
# 25                                     The Minion Game  0.854372
# 26                                    Merge the Tools!  0.926066
# 27                                 itertools.product()  0.980374
# 28                               collections.Counter()  0.984318
# 29                            itertools.permutations()  0.980007
# ..                                                 ...       ...
# 85              Validating and Parsing Email Addresses  0.887828
# 86                                      Hex Color Code  0.964350
# 87                                HTML Parser - Part 1  0.947900
# 88                                HTML Parser - Part 2  0.983180
# 89   Detect HTML Tags, Attributes and Attribute Values  0.978141
# 90                              XML 1 - Find the Score  0.975546
# 91                                      Validating UID  0.958290
# 92                      Validating Credit Card Numbers  0.951983
# 93                       XML2 - Find the Maximum Depth  0.968081
# 94          Standardize Mobile Number Using Decorators  0.977487
# 95                             Validating Postal Codes  0.851728
# 96                       Decorators 2 - Name Directory  0.907428
# 97                                       Matrix Script  0.877960
# 98                                         Words Score  0.954291
# 99                                              Arrays  0.958109
# 100                                  Shape and Reshape  0.962802
# 101                                  Default Arguments  0.806410
# 102                              Transpose and Flatten  0.969415
# 103                                        Concatenate  0.990601
# 104                                     Zeros and Ones  0.946406
# 105                                   Eye and Identity  0.941737
# 106                                  Array Mathematics  0.947421
# 107                               Floor, Ceil and Rint  0.963759
# 108                                       Sum and Prod  0.983712
# 109                                        Min and Max  0.986357
# 110                                 Mean, Var, and Std  0.948152
# 111                                      Dot and Cross  0.988531
# 112                                    Inner and Outer  0.985111
# 113                                        Polynomials  0.990737
# 114                                     Linear Algebra  0.944751
#
#                         분류정보             태그1  태그2  태그3
# 0               Introduction  변수, 상수, 기초 자료형  NaN  NaN
# 1               Introduction            흐름제어  NaN  NaN
# 2               Introduction              연산  NaN  NaN
# 3               Introduction              연산  NaN  NaN
# 4               Introduction            흐름제어  NaN  NaN
# 5               Introduction            흐름제어  NaN  NaN
# 6               Introduction            흐름제어  NaN  NaN
# 7           Basic Data Types          고급 자료형  NaN  NaN
# 8           Basic Data Types            자료구조  NaN  NaN
# 9           Basic Data Types            list  NaN  NaN
# 10          Basic Data Types      dictionary  NaN  NaN
# 11          Basic Data Types            list  NaN  NaN
# 12          Basic Data Types           tuple  NaN  NaN
# 13                   Strings          문자열 이용  NaN  NaN
# 14                   Strings          문자열 이용  NaN  NaN
# 15                   Strings          입출력 기초  NaN  NaN
# 16                   Strings          문자열 이용  NaN  NaN
# 17                   Strings          문자열 이용  NaN  NaN
# 18                   Strings           함수 사용  NaN  NaN
# 19                   Strings            흐름제어  NaN  NaN
# 20                   Strings          문자열 이용  NaN  NaN
# 21                   Strings              기타  NaN  NaN
# 22                   Strings              기타  NaN  NaN
# 23                   Strings            흐름제어  NaN  NaN
# 24                   Strings          문자열 이용  NaN  NaN
# 25                   Strings            흐름제어  NaN  NaN
# 26                   Strings          문자열 이용  NaN  NaN
# 27                 Itertools         모듈과 패키지  NaN  NaN
# 28               Collections         모듈과 패키지  NaN  NaN
# 29                 Itertools         모듈과 패키지  NaN  NaN
# ..                       ...             ...  ...  ...
# 85         Regex and Parsing           정규표현식  NaN  NaN
# 86         Regex and Parsing           정규표현식  NaN  NaN
# 87         Regex and Parsing              기타  NaN  NaN
# 88         Regex and Parsing              기타  NaN  NaN
# 89         Regex and Parsing              기타  NaN  NaN
# 90                       XML              기타  NaN  NaN
# 91         Regex and Parsing           정규표현식  NaN  NaN
# 92         Regex and Parsing           정규표현식  NaN  NaN
# 93                       XML              기타  NaN  NaN
# 94   Closures and Decorators          문자열 이용  NaN  NaN
# 95         Regex and Parsing           정규표현식  NaN  NaN
# 96   Closures and Decorators         모듈과 패키지  NaN  NaN
# 97         Regex and Parsing           정규표현식  NaN  NaN
# 98                 Debugging            list  NaN  NaN
# 99                     Numpy              기타  NaN  NaN
# 100                    Numpy              기타  NaN  NaN
# 101                Debugging       객체 지향적 사고  NaN  NaN
# 102                    Numpy              기타  NaN  NaN
# 103                    Numpy              기타  NaN  NaN
# 104                    Numpy              기타  NaN  NaN
# 105                    Numpy              기타  NaN  NaN
# 106                    Numpy              기타  NaN  NaN
# 107                    Numpy              기타  NaN  NaN
# 108                    Numpy              기타  NaN  NaN
# 109                    Numpy              기타  NaN  NaN
# 110                    Numpy              기타  NaN  NaN
# 111                    Numpy              기타  NaN  NaN
# 112                    Numpy              기타  NaN  NaN
# 113                    Numpy              기타  NaN  NaN
# 114                    Numpy              기타  NaN  NaN
#
# [115 rows x 7 columns]

# %%
df_bj['url'] = 'https://www.acmicpc.net/problem/' + df_bj['문제번호'].apply(str)

# %%
df_bj = df_bj[df_bj['사용여부'] != df_bj['사용여부']]

# %%
df_bj['태그1'] = df_bj['태그1'].map(lambda x: x.replace('동적프로그래밍', '동적 프로그래밍'))
df_bj['태그1'] = df_bj['태그1'].map(lambda x: x.replace('greedy', 'greedy algorithm'))
df_bj['태그1'] = df_bj['태그1'].map(lambda x: x.replace('greedy', 'greedy algorithm'))
df_hr['태그1'] = df_hr['태그1'].map(lambda x: x.replace('딕셔너리 사용', 'dictionary'))
df_hr['태그1'] = df_hr['태그1'].map(lambda x: x.replace('for 연산', '흐름제어'))
# Out:
# /Users/Cho/.pyenv/versions/3.7.2/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /Users/Cho/.pyenv/versions/3.7.2/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /Users/Cho/.pyenv/versions/3.7.2/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
df_bj2 = df_bj.merge(df_cate2,how='left',left_on=['태그1'],right_on=['소분류'])

# %%
df_hr2 = df_hr.merge(df_cate2,how='left',left_on=['태그1'],right_on=['소분류'])

# %%
df_hr3 = df_hr2[['문제제목', '정답률', '태그1', 'URL', '대분류', '중분류', '소분류']]

# %%
df_hr3.columns = ['문제제목', '정답률', '태그1', 'url', '대분류', '중분류', '소분류']

# %%
df_hr3.groupby(['대분류','중분류']).size()
# Out:
# 대분류  중분류
# 고급   1단계     5
#      2단계    38
# 중급   1단계    14
#      2단계    26
#      3단계     1
# 초급   1단계     8
#      2단계     9
#      3단계    14
# dtype: int64

# %%
df_bj3.groupby(['대분류','중분류']).size()
# Out:
# 대분류  중분류
# 고급   2단계    26
#      3단계    33
# 중급   1단계    14
#      2단계    16
#      3단계    10
# 초급   1단계    14
#      2단계    30
#      3단계    14
# dtype: int64

# %%
df_hr3['exbank'] = '해커랭크'
df_bj3['exbank'] = '백준'
# Out:
# /Users/Cho/.pyenv/versions/3.7.2/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /Users/Cho/.pyenv/versions/3.7.2/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
df_ex = pd.concat([df_hr3, df_bj3.dropna()])
# Out:
# /Users/Cho/.pyenv/versions/3.7.2/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.

# %%
df = pd.DataFrame({'대분류':['a','초급','초급','초급','중급','중급','중급','고급','고급','고급'],'중분류':['b','1단계','2단계','3단계','1단계','2단계','3단계','1단계','2단계','3단계']})

# %%
df.reset_index()
# Out:
#    index 대분류  중분류
# 0      0   a    b
# 1      1  초급  1단계
# 2      2  초급  2단계
# 3      3  초급  3단계
# 4      4  중급  1단계
# 5      5  중급  2단계
# 6      6  중급  3단계
# 7      7  고급  1단계
# 8      8  고급  2단계
# 9      9  고급  3단계

# %%
df_bj3 = df_bj2[['문제번호', '문제제목', '정답률', '태그1', 'url', '대분류', '중분류', '소분류']]

# %%
df_ex = df_ex.merge(df.reset_index(), on=['대분류', '중분류'])

# %%
df_ex.columns = ['exbank', 'url', '대분류', '문제번호', '문제제목', '소분류', '정답률', '중분류', '태그1','difficulty']

# %%
df_ex
# Out:
#     exbank                                                url 대분류     문제번호  \
# 0     해커랭크  https://www.hackerrank.com/challenges/py-hello...  초급      NaN
# 1     해커랭크  https://www.hackerrank.com/challenges/python-a...  초급      NaN
# 2     해커랭크  https://www.hackerrank.com/challenges/python-d...  초급      NaN
# 3     해커랭크  https://www.hackerrank.com/challenges/whats-yo...  초급      NaN
# 4     해커랭크  https://www.hackerrank.com/challenges/python-m...  초급      NaN
# 5     해커랭크  https://www.hackerrank.com/challenges/python-i...  초급      NaN
# 6     해커랭크        https://www.hackerrank.com/challenges/input  초급      NaN
# 7     해커랭크   https://www.hackerrank.com/challenges/any-or-all  초급      NaN
# 8       백준               https://www.acmicpc.net/problem/2557  초급   2557.0
# 9       백준               https://www.acmicpc.net/problem/1000  초급   1000.0
# 10      백준               https://www.acmicpc.net/problem/1001  초급   1001.0
# 11      백준               https://www.acmicpc.net/problem/7287  초급   7287.0
# 12      백준              https://www.acmicpc.net/problem/10172  초급  10172.0
# 13      백준              https://www.acmicpc.net/problem/10718  초급  10718.0
# 14      백준              https://www.acmicpc.net/problem/11718  초급  11718.0
# 15      백준              https://www.acmicpc.net/problem/11719  초급  11719.0
# 16      백준              https://www.acmicpc.net/problem/10998  초급  10998.0
# 17      백준               https://www.acmicpc.net/problem/1008  초급   1008.0
# 18      백준              https://www.acmicpc.net/problem/10869  초급  10869.0
# 19      백준              https://www.acmicpc.net/problem/10430  초급  10430.0
# 20      백준               https://www.acmicpc.net/problem/2558  초급   2558.0
# 21      백준               https://www.acmicpc.net/problem/3053  초급   3053.0
# 22    해커랭크   https://www.hackerrank.com/challenges/py-if-else  초급      NaN
# 23    해커랭크  https://www.hackerrank.com/challenges/python-l...  초급      NaN
# 24    해커랭크  https://www.hackerrank.com/challenges/write-a-...  초급      NaN
# 25    해커랭크  https://www.hackerrank.com/challenges/python-p...  초급      NaN
# 26    해커랭크  https://www.hackerrank.com/challenges/text-ali...  초급      NaN
# 27    해커랭크  https://www.hackerrank.com/challenges/alphabet...  초급      NaN
# 28    해커랭크  https://www.hackerrank.com/challenges/the-mini...  초급      NaN
# 29    해커랭크  https://www.hackerrank.com/challenges/triangle...  초급      NaN
# ..     ...                                                ...  ..      ...
# 242     백준               https://www.acmicpc.net/problem/1149  고급   1149.0
# 243     백준               https://www.acmicpc.net/problem/1932  고급   1932.0
# 244     백준               https://www.acmicpc.net/problem/2579  고급   2579.0
# 245     백준               https://www.acmicpc.net/problem/1463  고급   1463.0
# 246     백준               https://www.acmicpc.net/problem/1005  고급   1005.0
# 247     백준              https://www.acmicpc.net/problem/10844  고급  10844.0
# 248     백준               https://www.acmicpc.net/problem/2293  고급   2293.0
# 249     백준               https://www.acmicpc.net/problem/2156  고급   2156.0
# 250     백준               https://www.acmicpc.net/problem/1520  고급   1520.0
# 251     백준               https://www.acmicpc.net/problem/9251  고급   9251.0
# 252     백준              https://www.acmicpc.net/problem/11066  고급  11066.0
# 253     백준               https://www.acmicpc.net/problem/1912  고급   1912.0
# 254     백준               https://www.acmicpc.net/problem/9461  고급   9461.0
# 255     백준               https://www.acmicpc.net/problem/9252  고급   9252.0
# 256     백준               https://www.acmicpc.net/problem/1693  고급   1693.0
# 257     백준               https://www.acmicpc.net/problem/2098  고급   2098.0
# 258     백준               https://www.acmicpc.net/problem/2618  고급   2618.0
# 259     백준               https://www.acmicpc.net/problem/1315  고급   1315.0
# 260     백준              https://www.acmicpc.net/problem/11062  고급  11062.0
# 261     백준               https://www.acmicpc.net/problem/1562  고급   1562.0
# 262     백준               https://www.acmicpc.net/problem/2342  고급   2342.0
# 263     백준               https://www.acmicpc.net/problem/2449  고급   2449.0
# 264     백준              https://www.acmicpc.net/problem/10272  고급  10272.0
# 265     백준               https://www.acmicpc.net/problem/1958  고급   1958.0
# 266     백준               https://www.acmicpc.net/problem/4243  고급   4243.0
# 267     백준               https://www.acmicpc.net/problem/1344  고급   1344.0
# 268     백준              https://www.acmicpc.net/problem/13250  고급  13250.0
# 269     백준               https://www.acmicpc.net/problem/2066  고급   2066.0
# 270     백준               https://www.acmicpc.net/problem/3946  고급   3946.0
# 271     백준               https://www.acmicpc.net/problem/1413  고급   1413.0
#
#                                 문제제목             소분류       정답률  중분류  \
# 0    Say "Hello, World!" With Python  변수, 상수, 기초 자료형  0.974628  1단계
# 1               Arithmetic Operators              연산  0.986746  1단계
# 2                   Python: Division              연산  0.987764  1단계
# 3                  What's Your Name?          입출력 기초  0.979498  1단계
# 4                         Mod Divmod              연산  0.988857  1단계
# 5         Integers Come In All Sizes  변수, 상수, 기초 자료형  0.993011  1단계
# 6                            Input()          입출력 기초  0.957407  1단계
# 7                         Any or All              연산  0.943856  1단계
# 8                        Hello World          입출력 기초    47.34%  1단계
# 9                                A+B              연산    45.25%  1단계
# 10                               A-B              연산    72.07%  1단계
# 11                                등록          입출력 기초    47.84%  1단계
# 12                                 개          입출력 기초    37.07%  1단계
# 13                     We love kriii          입출력 기초    78.31%  1단계
# 14                          그대로 출력하기          입출력 기초    25.22%  1단계
# 15                        그대로 출력하기 2          입출력 기초    56.90%  1단계
# 16                               A×B              연산    76.80%  1단계
# 17                               A/B              연산    34.01%  1단계
# 18                              사칙연산              연산    58.34%  1단계
# 19                               나머지              연산    61.66%  1단계
# 20                             A+B 2              연산    75.46%  1단계
# 21                            택시 기하학              연산    41.75%  1단계
# 22                    Python If-Else            흐름제어  0.912253  2단계
# 23                             Loops            흐름제어   0.98422  2단계
# 24                  Write a function            흐름제어  0.902642  2단계
# 25                    Print Function            흐름제어  0.958743  2단계
# 26                    Text Alignment            흐름제어  0.981402  2단계
# 27                  Alphabet Rangoli            흐름제어  0.973757  2단계
# 28                   The Minion Game            흐름제어  0.854372  2단계
# 29                  Triangle Quest 2            흐름제어  0.951749  2단계
# ..                               ...             ...       ...  ...
# 242                            RGB거리        동적 프로그래밍    46.46%  3단계
# 243                           정수 삼각형        동적 프로그래밍    57.77%  3단계
# 244                           계단 오르기        동적 프로그래밍    38.92%  3단계
# 245                           1로 만들기        동적 프로그래밍    32.06%  3단계
# 246                        ACM Craft        동적 프로그래밍    18.20%  3단계
# 247                          쉬운 계단 수        동적 프로그래밍    28.46%  3단계
# 248                             동전 1        동적 프로그래밍    41.57%  3단계
# 249                           포도주 시식        동적 프로그래밍    34.38%  3단계
# 250                            내리막 길        동적 프로그래밍    26.71%  3단계
# 251                              LCS        동적 프로그래밍    41.97%  3단계
# 252                           파일 합치기        동적 프로그래밍    52.07%  3단계
# 253                              연속합        동적 프로그래밍    27.00%  3단계
# 254                           파도반 수열        동적 프로그래밍    38.32%  3단계
# 255                            LCS 2        동적 프로그래밍    41.69%  3단계
# 256                          트리 색칠하기        동적 프로그래밍    24.95%  3단계
# 257                           외판원 순회        동적 프로그래밍    26.05%  3단계
# 258                              경찰차        동적 프로그래밍    29.19%  3단계
# 259                              RPG        동적 프로그래밍    19.08%  3단계
# 260                            카드 게임        동적 프로그래밍    43.69%  3단계
# 261                             계단 수        동적 프로그래밍    45.27%  3단계
# 262           Dance Dance Revolution        동적 프로그래밍    32.86%  3단계
# 263                               전구        동적 프로그래밍    40.56%  3단계
# 264                      현상금 사냥꾼 김정은        동적 프로그래밍    43.68%  3단계
# 265                            LCS 3        동적 프로그래밍    48.91%  3단계
# 266                            보안 업체        동적 프로그래밍    30.29%  3단계
# 267                               축구        동적 프로그래밍    56.39%  3단계
# 268                           주사위 게임        동적 프로그래밍    70.61%  3단계
# 269                             카드놀이        동적 프로그래밍    43.83%  3단계
# 270                            랜덤 걷기        동적 프로그래밍    46.15%  3단계
# 271                         박스 안의 열쇠        동적 프로그래밍    37.63%  3단계
#
#                 태그1  difficulty
# 0    변수, 상수, 기초 자료형           1
# 1                연산           1
# 2                연산           1
# 3            입출력 기초           1
# 4                연산           1
# 5    변수, 상수, 기초 자료형           1
# 6            입출력 기초           1
# 7                연산           1
# 8            입출력 기초           1
# 9                연산           1
# 10               연산           1
# 11           입출력 기초           1
# 12           입출력 기초           1
# 13           입출력 기초           1
# 14           입출력 기초           1
# 15           입출력 기초           1
# 16               연산           1
# 17               연산           1
# 18               연산           1
# 19               연산           1
# 20               연산           1
# 21               연산           1
# 22             흐름제어           2
# 23             흐름제어           2
# 24             흐름제어           2
# 25             흐름제어           2
# 26             흐름제어           2
# 27             흐름제어           2
# 28             흐름제어           2
# 29             흐름제어           2
# ..              ...         ...
# 242        동적 프로그래밍           9
# 243        동적 프로그래밍           9
# 244        동적 프로그래밍           9
# 245        동적 프로그래밍           9
# 246        동적 프로그래밍           9
# 247        동적 프로그래밍           9
# 248        동적 프로그래밍           9
# 249        동적 프로그래밍           9
# 250        동적 프로그래밍           9
# 251        동적 프로그래밍           9
# 252        동적 프로그래밍           9
# 253        동적 프로그래밍           9
# 254        동적 프로그래밍           9
# 255        동적 프로그래밍           9
# 256        동적 프로그래밍           9
# 257        동적 프로그래밍           9
# 258        동적 프로그래밍           9
# 259        동적 프로그래밍           9
# 260        동적 프로그래밍           9
# 261        동적 프로그래밍           9
# 262        동적 프로그래밍           9
# 263        동적 프로그래밍           9
# 264        동적 프로그래밍           9
# 265        동적 프로그래밍           9
# 266        동적 프로그래밍           9
# 267        동적 프로그래밍           9
# 268        동적 프로그래밍           9
# 269        동적 프로그래밍           9
# 270        동적 프로그래밍           9
# 271        동적 프로그래밍           9
#
# [272 rows x 10 columns]

# %%
# df_cate2 = df_cate[['대분류','중분류','소분류']].drop_duplicates()

# %%
# df_cate2

# %%
{'model': 'problem.problemex',
  'pk': 2,
  'fields': {'title': '테스트용도',
   'url': 'https://www.acmicpc.net/problem/10171',
   'exbank': '백준',
   'pid': 10171,
   'difficulty': 1,
   'cate1': None,
   'cate2': None,
   'cate3': None}}

# %%
# df_hacker['exbank'] = '해커랭크'
# df_hacker['model'] = 'problem.problemex'

# %%
df_hacker.reset_index(inplace=True)

# %%
df_hacker['index'] += 4

# %%
# df_hacker.columns = ['pk', 'url', 'title', 'correct_ratio', '분류정보',
#                      'tag1', 'tag2', 'tag3', 'exbank', 'model']

# %%
df_ex.columns = ['exbank', 'url', 'cate1', 'pid', 'title', 'cate3', 'correct_ratio', 'cate2', '태그1','difficulty']

# %%
def check_ratio(r):
    if '%' in str(r):
        return float(r.replace('%','')) * 0.01
    return r
df_ex.correct_ratio = df_ex.correct_ratio.map(lambda x: check_ratio(x))

# %%
hacker_json = df_ex[['url', 'title','exbank', 'cate1', 'cate2', 'cate3', 'correct_ratio', 'pid', 'difficulty']].to_json(orient='records')

# %%
hacker_json = json.loads(hacker_json)

# %%
hacker_json = [{'fields':hack} for hack in hacker_json]

# %%
hacker_json
# Out:
# [{'fields': {'url': 'https://www.hackerrank.com/challenges/py-hello-world',
#    'title': 'Say "Hello, World!" With Python',
#    'exbank': '해커랭크',
#    'cate1': '초급',
#    'cate2': '1단계',
#    'cate3': '변수, 상수, 기초 자료형',
#    'correct_ratio': 0.974628,
#    'pid': None,
#    'difficulty': 1}},
#  {'fields': {'url': 'https://www.hackerrank.com/challenges/python-arithmetic-operators',
#    'title': 'Arithmetic Operators',
#    'exbank': '해커랭크',
#    'cate1': '초급',
#    'cate2': '1단계',
#    'cate3': '연산',
#    'correct_ratio': 0.986746,
#    'pid': None,
#    'difficulty': 1}},
#  {'fields': {'url': 'https://www.hackerrank.com/challenges/python-division',
#    'title': 'Python: Division',
#    'exbank': '해커랭크',
#    'cate1': '초급',
#    'cate2': '1단계',
#    'cate3': '연산',
#    'correct_ratio': 0.987764,
#    'pid': None,
#    'difficulty': 1}},
#  {'fields': {'url': 'https://www.hackerrank.com/challenges/whats-your-name',
#    'title': "What's Your Name?",
#    'exbank': '해커랭크',
#    'cate1': '초급',
#    'cate2': '1단계',
#    'cate3': '입출력 기초',
#    'correct_ratio': 0.979498,
#    'pid': None,
#    'difficulty': 1}},
#  {'fields': {'url': 'https://www.hackerrank.com/challenges/python-mod-divmod',
#    'title': 'Mod Divmod',
#    'exbank': '해커랭크',
#    'cate1': '초급',
#    'cate2': '1단계',
#    'cate3': '연산',
#    'correct_ratio': 0.988857,
#    'pid': None,
#    'difficulty': 1}},
#  {'fields': {'url': 'https://www.hackerrank.com/challenges/python-integers-come-in-all-sizes',
#    'title': 'Integers Come In All Sizes',
#    'exbank': '해커랭크',
#    'cate1': '초급',
#    'cate2': '1단계',
#    'cate3': '변수, 상수, 기초 자료형',
#    'correct_ratio': 0.993011,
#    'pid': None,
#    'difficulty': 1}},
#  {'fields': {'url': 'https://www.hackerrank.com/challenges/input',
#    'title': 'Input()',
#    'exbank': '해커랭크',
#    'cate1': '초급',
#    'cate2': '1단계',
#    'cate3': '입출력 기초',
#    'correct_ratio': 0.957407,
#    'pid': None,
#    'difficulty': 1}},
#  {'fields': {'url': 'https://www.hackerrank.com/challenges/any-or-all',
#    'title': 'Any or All',
#    'exbank': '해커랭크',
#    'cate1': '초급',
#    'cate2': '1단계',
#    'cate3': '연산',
#    'correct_ratio': 0.943856,
#    'pid': None,
#    'difficulty': 1}},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/2557',
#    'title': 'Hello World',
#    'exbank': '백준',
#    'cate1': '초급',
#    'cate2': '1단계',
#    'cate3': '입출력 기초',
#    'correct_ratio': 0.4734,
#    'pid': 2557.0,
#    'difficulty': 1}},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/1000',
#    'title': 'A+B',
#    'exbank': '백준',
#    'cate1': '초급',
#    'cate2': '1단계',
#    'cate3': '연산',
#    'correct_ratio': 0.4525,
#    'pid': 1000.0,
#    'difficulty': 1}},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/1001',
#    'title': 'A-B',
#    'exbank': '백준',
#    'cate1': '초급',
#    'cate2': '1단계',
#    'cate3': '연산',
#    'correct_ratio': 0.7207,
#    'pid': 1001.0,
#    'difficulty': 1}},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/7287',
#    'title': '등록',
#    'exbank': '백준',
#    'cate1': '초급',
#    'cate2': '1단계',
#    'cate3': '입출력 기초',
#    'correct_ratio': 0.4784,
#    'pid': 7287.0,
#    'difficulty': 1}},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/10172',
#    'title': '개',
#    'exbank': '백준',
#    'cate1': '초급',
#    'cate2': '1단계',
#    'cate3': '입출력 기초',
#    'correct_ratio': 0.3707,
#    'pid': 10172.0,
#    'difficulty': 1}},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/10718',
#    'title': 'We love kriii',
#    'exbank': '백준',
#    'cate1': '초급',
#    'cate2': '1단계',
#    'cate3': '입출력 기초',
#    'correct_ratio': 0.7831,
#    'pid': 10718.0,
#    'difficulty': 1}},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/11718',
#    'title': '그대로 출력하기',
#    'exbank': '백준',
#    'cate1': '초급',
#    'cate2': '1단계',
#    'cate3': '입출력 기초',
#    'correct_ratio': 0.2522,
#    'pid': 11718.0,
#    'difficulty': 1}},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/11719',
#    'title': '그대로 출력하기 2',
#    'exbank': '백준',
#    'cate1': '초급',
#    'cate2': '1단계',
#    'cate3': '입출력 기초',
#    'correct_ratio': 0.569,
#    'pid': 11719.0,
#    'difficulty': 1}},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/10998',
#    'title': 'A×B',
#    'exbank': '백준',
#    'cate1': '초급',
#    'cate2': '1단계',
#    'cate3': '연산',
#    'correct_ratio': 0.768,
#    'pid': 10998.0,
#    'difficulty': 1}},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/1008',
#    'title': 'A/B',
#    'exbank': '백준',
#    'cate1': '초급',
#    'cate2': '1단계',
#    'cate3': '연산',
#    'correct_ratio': 0.3401,
#    'pid': 1008.0,
#    'difficulty': 1}},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/10869',
#    'title': '사칙연산',
#    'exbank': '백준',
#    'cate1': '초급',
#    'cate2': '1단계',
#    'cate3': '연산',
#    'correct_ratio': 0.5834,
#    'pid': 10869.0,
#    'difficulty': 1}},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/10430',
#    'title': '나머지',
#    'exbank': '백준',
#    'cate1': '초급',
#    'cate2': '1단계',
#    'cate3': '연산',
#    'correct_ratio': 0.6166,
#    'pid': 10430.0,
#    'difficulty': 1}},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/2558',
#    'title': 'A+B 2',
#    'exbank': '백준',
#    'cate1': '초급',
#    'cate2': '1단계',
#    'cate3': '연산',
#    'correct_ratio': 0.7546,
#    'pid': 2558.0,
#    'difficulty': 1}},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/3053',
#    'title': '택시 기하학',
#    'exbank': '백준',
#    'cate1': '초급',
#    'cate2': '1단계',
#    'cate3': '연산',
#    'correct_ratio': 0.4175,
#    'pid': 3053.0,
#    'difficulty': 1}},
#  {'fields': {'url': 'https://www.hackerrank.com/challenges/py-if-else',
#    'title': 'Python If-Else',
#    'exbank': '해커랭크',
#    'cate1': '초급',
#    'cate2': '2단계',
#    'cate3': '흐름제어',
#    'correct_ratio': 0.912253,
#    'pid': None,
#    'difficulty': 2}},
#  {'fields': {'url': 'https://www.hackerrank.com/challenges/python-loops',
#    'title': 'Loops',
#    'exbank': '해커랭크',
#    'cate1': '초급',
#    'cate2': '2단계',
#    'cate3': '흐름제어',
#    'correct_ratio': 0.98422,
#    'pid': None,
#    'difficulty': 2}},
#  {'fields': {'url': 'https://www.hackerrank.com/challenges/write-a-function',
#    'title': 'Write a function',
#    'exbank': '해커랭크',
#    'cate1': '초급',
#    'cate2': '2단계',
#    'cate3': '흐름제어',
#    'correct_ratio': 0.902642,
#    'pid': None,
#    'difficulty': 2}},
#  {'fields': {'url': 'https://www.hackerrank.com/challenges/python-print',
#    'title': 'Print Function',
#    'exbank': '해커랭크',
#    'cate1': '초급',
#    'cate2': '2단계',
#    'cate3': '흐름제어',
#    'correct_ratio': 0.958743,
#    'pid': None,
#    'difficulty': 2}},
#  {'fields': {'url': 'https://www.hackerrank.com/challenges/text-alignment',
#    'title': 'Text Alignment',
#    'exbank': '해커랭크',
#    'cate1': '초급',
#    'cate2': '2단계',
#    'cate3': '흐름제어',
#    'correct_ratio': 0.981402,
#    'pid': None,
#    'difficulty': 2}},
#  {'fields': {'url': 'https://www.hackerrank.com/challenges/alphabet-rangoli',
#    'title': 'Alphabet Rangoli',
#    'exbank': '해커랭크',
#    'cate1': '초급',
#    'cate2': '2단계',
#    'cate3': '흐름제어',
#    'correct_ratio': 0.973757,
#    'pid': None,
#    'difficulty': 2}},
#  {'fields': {'url': 'https://www.hackerrank.com/challenges/the-minion-game',
#    'title': 'The Minion Game',
#    'exbank': '해커랭크',
#    'cate1': '초급',
#    'cate2': '2단계',
#    'cate3': '흐름제어',
#    'correct_ratio': 0.854372,
#    'pid': None,
#    'difficulty': 2}},
#  {'fields': {'url': 'https://www.hackerrank.com/challenges/triangle-quest-2',
#    'title': 'Triangle Quest 2',
#    'exbank': '해커랭크',
#    'cate1': '초급',
#    'cate2': '2단계',
#    'cate3': '흐름제어',
#    'correct_ratio': 0.951749,
#    'pid': None,
#    'difficulty': 2}},
#  {'fields': {'url': 'https://www.hackerrank.com/challenges/python-quest-1',
#    'title': 'Triangle Quest',
#    'exbank': '해커랭크',
#    'cate1': '초급',
#    'cate2': '2단계',
#    'cate3': '흐름제어',
#    'correct_ratio': 0.915984,
#    'pid': None,
#    'difficulty': 2}},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/2839',
#    'title': '설탕 배달',
#    'exbank': '백준',
#    'cate1': '초급',
#    'cate2': '2단계',
#    'cate3': '흐름제어',
#    'correct_ratio': 0.2885,
#    'pid': 2839.0,
#    'difficulty': 2}},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/2741',
#    'title': 'N 찍기',
#    'exbank': '백준',
#    'cate1': '초급',
#    'cate2': '2단계',
#    'cate3': '흐름제어',
#    'correct_ratio': 0.4498,
#    'pid': 2741.0,
#    'difficulty': 2}},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/2742',
#    'title': '기찍 N',
#    'exbank': '백준',
#    'cate1': '초급',
#    'cate2': '2단계',
#    'cate3': '흐름제어',
#    'correct_ratio': 0.648,
#    'pid': 2742.0,
#    'difficulty': 2}},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/2739',
#    'title': '구구단',
#    'exbank': '백준',
#    'cate1': '초급',
#    'cate2': '2단계',
#    'cate3': '흐름제어',
#    'correct_ratio': 0.5597,
#    'pid': 2739.0,
#    'difficulty': 2}},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/2438',
#    'title': '별 찍기 1',
#    'exbank': '백준',
#    'cate1': '초급',
#    'cate2': '2단계',
#    'cate3': '흐름제어',
#    'correct_ratio': 0.6157,
#    'pid': 2438.0,
#    'difficulty': 2}},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/2439',
#    'title': '별 찍기 2',
#    'exbank': '백준',
#    'cate1': '초급',
#    'cate2': '2단계',
#    'cate3': '흐름제어',
#    'correct_ratio': 0.5935,
#    'pid': 2439.0,
#    'difficulty': 2}},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/2440',
#    'title': '별 찍기 3',
#    'exbank': '백준',
#    'cate1': '초급',
#    'cate2': '2단계',
#    'cate3': '흐름제어',
#    'correct_ratio': 0.6661,
#    'pid': 2440.0,
#    'difficulty': 2}},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/2441',
#    'title': '별 찍기 4',
#    'exbank': '백준',
#    'cate1': '초급',
#    'cate2': '2단계',
#    'cate3': '흐름제어',
#    'correct_ratio': 0.7335,
#    'pid': 2441.0,
#    'difficulty': 2}},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/1924',
#    'title': '2007년',
#    'exbank': '백준',
#    'cate1': '초급',
#    'cate2': '2단계',
#    'cate3': '흐름제어',
#    'correct_ratio': 0.4414,
#    'pid': 1924.0,
#    'difficulty': 2}},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/8393',
#    'title': '합',
#    'exbank': '백준',
#    'cate1': '초급',
#    'cate2': '2단계',
#    'cate3': '흐름제어',
#    'correct_ratio': 0.7356,
#    'pid': 8393.0,
#    'difficulty': 2}},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/11720',
#    'title': '숫자의 합',
#    'exbank': '백준',
#    'cate1': '초급',
#    'cate2': '2단계',
#    'cate3': '흐름제어',
#    'correct_ratio': 0.466,
#    'pid': 11720.0,
#    'difficulty': 2}},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/11721',
#    'title': '열 개씩 끊어 출력하기',
#    'exbank': '백준',
#    'cate1': '초급',
#    'cate2': '2단계',
#    'cate3': '흐름제어',
#    'correct_ratio': 0.5122,
#    'pid': 11721.0,
#    'difficulty': 2}},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/15552',
#    'title': '빠른 A+B',
#    'exbank': '백준',
#    'cate1': '초급',
#    'cate2': '2단계',
#    'cate3': '흐름제어',
#    'correct_ratio': 0.5058,
#    'pid': 15552.0,
#    'difficulty': 2}},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/9498',
#    'title': '시험 성적',
#    'exbank': '백준',
#    'cate1': '초급',
#    'cate2': '2단계',
#    'cate3': '흐름제어',
#    'correct_ratio': 0.6198,
#    'pid': 9498.0,
#    'difficulty': 2}},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/10817',
#    'title': '세 수',
#    'exbank': '백준',
#    'cate1': '초급',
#    'cate2': '2단계',
#    'cate3': '흐름제어',
#    'correct_ratio': 0.4714,
#    'pid': 10817.0,
#    'difficulty': 2}},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/10871',
#    'title': 'X보다 작은 수',
#    'exbank': '백준',
#    'cate1': '초급',
#    'cate2': '2단계',
#    'cate3': '흐름제어',
#    'correct_ratio': 0.5817,
#    'pid': 10871.0,
#    'difficulty': 2}},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/1546',
#    'title': '평균',
#    'exbank': '백준',
#    'cate1': '초급',
#    'cate2': '2단계',
#    'cate3': '흐름제어',
#    'correct_ratio': 0.4705,
#    'pid': 1546.0,
#    'difficulty': 2}},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/4344',
#    'title': '평균은 넘겠지',
#    'exbank': '백준',
#    'cate1': '초급',
#    'cate2': '2단계',
#    'cate3': '흐름제어',
#    'correct_ratio': 0.3844,
#    'pid': 4344.0,
#    'difficulty': 2}},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/1110',
#    'title': '더하기 사이클',
#    'exbank': '백준',
#    'cate1': '초급',
#    'cate2': '2단계',
#    'cate3': '흐름제어',
#    'correct_ratio': 0.502,
#    'pid': 1110.0,
#    'difficulty': 2}},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/4673',
#    'title': '셀프 넘버',
#    'exbank': '백준',
#    'cate1': '초급',
#    'cate2': '2단계',
#    'cate3': '흐름제어',
#    'correct_ratio': 0.5312,
#    'pid': 4673.0,
#    'difficulty': 2}},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/2448',
#    'title': '별 찍기 11',
#    'exbank': '백준',
#    'cate1': '초급',
#    'cate2': '2단계',
#    'cate3': '흐름제어',
#    'correct_ratio': 0.3631,
#    'pid': 2448.0,
#    'difficulty': 2}},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/2747',
#    'title': '피보나치 수',
#    'exbank': '백준',
#    'cate1': '초급',
#    'cate2': '2단계',
#    'cate3': '흐름제어',
#    'correct_ratio': 0.4687,
#    'pid': 2747.0,
#    'difficulty': 2}},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/1676',
#    'title': '팩토리얼 0의 개수',
#    'exbank': '백준',
#    'cate1': '초급',
#    'cate2': '2단계',
#    'cate3': '흐름제어',
#    'correct_ratio': 0.4607,
#    'pid': 1676.0,
#    'difficulty': 2}},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/6591',
#    'title': '이항 쇼다운',
#    'exbank': '백준',
#    'cate1': '초급',
#    'cate2': '2단계',
#    'cate3': '흐름제어',
#    'correct_ratio': 0.2399,
#    'pid': 6591.0,
#    'difficulty': 2}},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/2490',
#    'title': '윷놀이',
#    'exbank': '백준',
#    'cate1': '초급',
#    'cate2': '2단계',
#    'cate3': '흐름제어',
#    'correct_ratio': 0.5909,
#    'pid': 2490.0,
#    'difficulty': 2}},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/1022',
#    'title': '소용돌이 예쁘게 출력하기',
#    'exbank': '백준',
#    'cate1': '초급',
#    'cate2': '2단계',
#    'cate3': '흐름제어',
#    'correct_ratio': 0.3136,
#    'pid': 1022.0,
#    'difficulty': 2}},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/2455',
#    'title': '지능형 기차',
#    'exbank': '백준',
#    'cate1': '초급',
#    'cate2': '2단계',
#    'cate3': '흐름제어',
#    'correct_ratio': 0.8004,
#    'pid': 2455.0,
#    'difficulty': 2}},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/1094',
#    'title': '막대기',
#    'exbank': '백준',
#    'cate1': '초급',
#    'cate2': '2단계',
#    'cate3': '흐름제어',
#    'correct_ratio': 0.7328,
#    'pid': 1094.0,
#    'difficulty': 2}},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/1057',
#    'title': '토너먼트',
#    'exbank': '백준',
#    'cate1': '초급',
#    'cate2': '2단계',
#    'cate3': '흐름제어',
#    'correct_ratio': 0.5499,
#    'pid': 1057.0,
#    'difficulty': 2}},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/1024',
#    'title': '수열의 합',
#    'exbank': '백준',
#    'cate1': '초급',
#    'cate2': '2단계',
#    'cate3': '흐름제어',
#    'correct_ratio': 0.2582,
#    'pid': 1024.0,
#    'difficulty': 2}},
#  {'fields': {'url': 'https://www.hackerrank.com/challenges/list-comprehensions',
#    'title': 'List Comprehensions',
#    'exbank': '해커랭크',
#    'cate1': '중급',
#    'cate2': '2단계',
#    'cate3': '고급 자료형',
#    'correct_ratio': 0.984657,
#    'pid': None,
#    'difficulty': 5}},
#  {'fields': {'url': 'https://www.hackerrank.com/challenges/find-second-maximum-number-in-a-list',
#    'title': 'Find the Runner-Up Score!',
#    'exbank': '해커랭크',
#    'cate1': '중급',
#    'cate2': '2단계',
#    'cate3': '자료구조',
#    'correct_ratio': 0.939112,
#    'pid': None,
#    'difficulty': 5}},
#  {'fields': {'url': 'https://www.hackerrank.com/challenges/itertools-product',
#    'title': 'itertools.product()',
#    'exbank': '해커랭크',
#    'cate1': '중급',
#    'cate2': '2단계',
#    'cate3': '모듈과 패키지',
#    'correct_ratio': 0.980374,
#    'pid': None,
#    'difficulty': 5}},
#  {'fields': {'url': 'https://www.hackerrank.com/challenges/collections-counter',
#    'title': 'collections.Counter()',
#    'exbank': '해커랭크',
#    'cate1': '중급',
#    'cate2': '2단계',
#    'cate3': '모듈과 패키지',
#    'correct_ratio': 0.984318,
#    'pid': None,
#    'difficulty': 5}},
#  {'fields': {'url': 'https://www.hackerrank.com/challenges/itertools-permutations',
#    'title': 'itertools.permutations()',
#    'exbank': '해커랭크',
#    'cate1': '중급',
#    'cate2': '2단계',
#    'cate3': '모듈과 패키지',
#    'correct_ratio': 0.980007,
#    'pid': None,
#    'difficulty': 5}},
#  {'fields': {'url': 'https://www.hackerrank.com/challenges/polar-coordinates',
#    'title': 'Polar Coordinates',
#    'exbank': '해커랭크',
#    'cate1': '중급',
#    'cate2': '2단계',
#    'cate3': '모듈과 패키지',
#    'correct_ratio': 0.944711,
#    'pid': None,
#    'difficulty': 5}},
#  {'fields': {'url': 'https://www.hackerrank.com/challenges/py-introduction-to-sets',
#    'title': 'Introduction to Sets',
#    'exbank': '해커랭크',
#    'cate1': '중급',
#    'cate2': '2단계',
#    'cate3': '고급 자료형',
#    'correct_ratio': 0.982999,
#    'pid': None,
#    'difficulty': 5}},
#  {'fields': {'url': 'https://www.hackerrank.com/challenges/calendar-module',
#    'title': 'Calendar Module',
#    'exbank': '해커랭크',
#    'cate1': '중급',
#    'cate2': '2단계',
#    'cate3': '모듈과 패키지',
#    'correct_ratio': 0.972119,
#    'pid': None,
#    'difficulty': 5}},
#  {'fields': {'url': 'https://www.hackerrank.com/challenges/py-collections-namedtuple',
#    'title': 'Collections.namedtuple()',
#    'exbank': '해커랭크',
#    'cate1': '중급',
#    'cate2': '2단계',
#    'cate3': '모듈과 패키지',
#    'correct_ratio': 0.978824,
#    'pid': None,
#    'difficulty': 5}},
#  {'fields': {'url': 'https://www.hackerrank.com/challenges/python-time-delta',
#    'title': 'Time Delta',
#    'exbank': '해커랭크',
#    'cate1': '중급',
#    'cate2': '2단계',
#    'cate3': '모듈과 패키지',
#    'correct_ratio': 0.916956,
#    'pid': None,
#    'difficulty': 5}},
#  {'fields': {'url': 'https://www.hackerrank.com/challenges/find-angle',
#    'title': 'Find Angle MBC',
#    'exbank': '해커랭크',
#    'cate1': '중급',
#    'cate2': '2단계',
#    'cate3': '모듈과 패키지',
#    'correct_ratio': 0.871596,
#    'pid': None,
#    'difficulty': 5}},
#  {'fields': {'url': 'https://www.hackerrank.com/challenges/no-idea',
#    'title': 'No Idea!',
#    'exbank': '해커랭크',
#    'cate1': '중급',
#    'cate2': '2단계',
#    'cate3': '모듈과 패키지',
#    'correct_ratio': 0.861785,
#    'pid': None,
#    'difficulty': 5}},
#  {'fields': {'url': 'https://www.hackerrank.com/challenges/py-collections-ordereddict',
#    'title': 'Collections.OrderedDict()',
#    'exbank': '해커랭크',
#    'cate1': '중급',
#    'cate2': '2단계',
#    'cate3': '모듈과 패키지',
#    'correct_ratio': 0.987974,
#    'pid': None,
#    'difficulty': 5}},
#  {'fields': {'url': 'https://www.hackerrank.com/challenges/symmetric-difference',
#    'title': 'Symmetric Difference',
#    'exbank': '해커랭크',
#    'cate1': '중급',
#    'cate2': '2단계',
#    'cate3': '모듈과 패키지',
#    'correct_ratio': 0.981304,
#    'pid': None,
#    'difficulty': 5}},
#  {'fields': {'url': 'https://www.hackerrank.com/challenges/itertools-combinations',
#    'title': 'itertools.combinations()',
#    'exbank': '해커랭크',
#    'cate1': '중급',
#    'cate2': '2단계',
#    'cate3': '모듈과 패키지',
#    'correct_ratio': 0.976345,
#    'pid': None,
#    'difficulty': 5}},
#  {'fields': {'url': 'https://www.hackerrank.com/challenges/itertools-combinations-with-replacement',
#    'title': 'itertools.combinations_with_replacement()',
#    'exbank': '해커랭크',
#    'cate1': '중급',
#    'cate2': '2단계',
#    'cate3': '모듈과 패키지',
#    'correct_ratio': 0.989537,
#    'pid': None,
#    'difficulty': 5}},
#  {'fields': {'url': 'https://www.hackerrank.com/challenges/py-collections-deque',
#    'title': 'Collections.deque()',
#    'exbank': '해커랭크',
#    'cate1': '중급',
#    'cate2': '2단계',
#    'cate3': '모듈과 패키지',
#    'correct_ratio': 0.984722,
#    'pid': None,
#    'difficulty': 5}},
#  {'fields': {'url': 'https://www.hackerrank.com/challenges/compress-the-string',
#    'title': 'Compress the String!',
#    'exbank': '해커랭크',
#    'cate1': '중급',
#    'cate2': '2단계',
#    'cate3': '모듈과 패키지',
#    'correct_ratio': 0.977239,
#    'pid': None,
#    'difficulty': 5}},
#  {'fields': {'url': 'https://www.hackerrank.com/challenges/piling-up',
#    'title': 'Piling Up!',
#    'exbank': '해커랭크',
#    'cate1': '중급',
#    'cate2': '2단계',
#    'cate3': '자료구조',
#    'correct_ratio': 0.897481,
#    'pid': None,
#    'difficulty': 5}},
#  {'fields': {'url': 'https://www.hackerrank.com/challenges/iterables-and-iterators',
#    'title': 'Iterables and Iterators',
#    'exbank': '해커랭크',
#    'cate1': '중급',
#    'cate2': '2단계',
#    'cate3': '모듈과 패키지',
#    'correct_ratio': 0.966448,
#    'pid': None,
#    'difficulty': 5}},
#  {'fields': {'url': 'https://www.hackerrank.com/challenges/maximize-it',
#    'title': 'Maximize It!',
#    'exbank': '해커랭크',
#    'cate1': '중급',
#    'cate2': '2단계',
#    'cate3': '모듈과 패키지',
#    'correct_ratio': 0.81415,
#    'pid': None,
#    'difficulty': 5}},
#  {'fields': {'url': 'https://www.hackerrank.com/challenges/py-check-subset',
#    'title': 'Check Subset',
#    'exbank': '해커랭크',
#    'cate1': '중급',
#    'cate2': '2단계',
#    'cate3': '고급 자료형',
#    'correct_ratio': 0.986416,
#    'pid': None,
#    'difficulty': 5}},
#  {'fields': {'url': 'https://www.hackerrank.com/challenges/py-check-strict-superset',
#    'title': 'Check Strict Superset',
#    'exbank': '해커랭크',
#    'cate1': '중급',
#    'cate2': '2단계',
#    'cate3': '고급 자료형',
#    'correct_ratio': 0.95533,
#    'pid': None,
#    'difficulty': 5}},
#  {'fields': {'url': 'https://www.hackerrank.com/challenges/map-and-lambda-expression',
#    'title': 'Map and Lambda Function',
#    'exbank': '해커랭크',
#    'cate1': '중급',
#    'cate2': '2단계',
#    'cate3': '고급 자료형',
#    'correct_ratio': 0.940121,
#    'pid': None,
#    'difficulty': 5}},
#  {'fields': {'url': 'https://www.hackerrank.com/challenges/reduce-function',
#    'title': 'Reduce Function',
#    'exbank': '해커랭크',
#    'cate1': '중급',
#    'cate2': '2단계',
#    'cate3': '고급 자료형',
#    'correct_ratio': 0.985904,
#    'pid': None,
#    'difficulty': 5}},
#  {'fields': {'url': 'https://www.hackerrank.com/challenges/decorators-2-name-directory',
#    'title': 'Decorators 2 - Name Directory',
#    'exbank': '해커랭크',
#    'cate1': '중급',
#    'cate2': '2단계',
#    'cate3': '모듈과 패키지',
#    'correct_ratio': 0.907428,
#    'pid': None,
#    'difficulty': 5}},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/10828',
#    'title': '스택',
#    'exbank': '백준',
#    'cate1': '중급',
#    'cate2': '2단계',
#    'cate3': '자료구조',
#    'correct_ratio': 0.4114,
#    'pid': 10828.0,
#    'difficulty': 5}},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/1874',
#    'title': '스택 수열',
#    'exbank': '백준',
#    'cate1': '중급',
#    'cate2': '2단계',
#    'cate3': '자료구조',
#    'correct_ratio': 0.2892,
#    'pid': 1874.0,
#    'difficulty': 5}},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/9012',
#    'title': '괄호',
#    'exbank': '백준',
#    'cate1': '중급',
#    'cate2': '2단계',
#    'cate3': '자료구조',
#    'correct_ratio': 0.3901,
#    'pid': 9012.0,
#    'difficulty': 5}},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/2504',
#    'title': '괄호의 값',
#    'exbank': '백준',
#    'cate1': '중급',
#    'cate2': '2단계',
#    'cate3': '자료구조',
#    'correct_ratio': 0.2839,
#    'pid': 2504.0,
#    'difficulty': 5}},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/10845',
#    'title': '큐',
#    'exbank': '백준',
#    'cate1': '중급',
#    'cate2': '2단계',
#    'cate3': '자료구조',
#    'correct_ratio': 0.5073,
#    'pid': 10845.0,
#    'difficulty': 5}},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/1260',
#    'title': 'DFS와 BFS',
#    'exbank': '백준',
#    'cate1': '중급',
#    'cate2': '2단계',
#    'cate3': '자료구조',
#    'correct_ratio': 0.2942,
#    'pid': 1260.0,
#    'difficulty': 5}},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/1966',
#    'title': '프린터 큐',
#    'exbank': '백준',
#    'cate1': '중급',
#    'cate2': '2단계',
#    'cate3': '자료구조',
#    'correct_ratio': 0.5267,
#    'pid': 1966.0,
#    'difficulty': 5}},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/11866',
#    'title': '조세퍼스 문제 0',
#    'exbank': '백준',
#    'cate1': '중급',
#    'cate2': '2단계',
#    'cate3': '자료구조',
#    'correct_ratio': 0.5901,
#    'pid': 11866.0,
#    'difficulty': 5}},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/1158',
#    'title': '조세퍼스 문제',
#    'exbank': '백준',
#    'cate1': '중급',
#    'cate2': '2단계',
#    'cate3': '자료구조',
#    'correct_ratio': 0.5091,
#    'pid': 1158.0,
#    'difficulty': 5}},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/10866',
#    'title': '덱',
#    'exbank': '백준',
#    'cate1': '중급',
#    'cate2': '2단계',
#    'cate3': '자료구조',
#    'correct_ratio': 0.5398,
#    'pid': 10866.0,
#    'difficulty': 5}},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/1021',
#    'title': '회전하는 큐',
#    'exbank': '백준',
#    'cate1': '중급',
#    'cate2': '2단계',
#    'cate3': '자료구조',
#    'correct_ratio': 0.3947,
#    'pid': 1021.0,
#    'difficulty': 5}},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/5430',
#    'title': 'AC',
#    'exbank': '백준',
#    'cate1': '중급',
#    'cate2': '2단계',
#    'cate3': '자료구조',
#    'correct_ratio': 0.1917,
#    'pid': 5430.0,
#    'difficulty': 5}},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/1991',
#    'title': '트리 순회',
#    'exbank': '백준',
#    'cate1': '중급',
#    'cate2': '2단계',
#    'cate3': '자료구조',
#    'correct_ratio': 0.6195,
#    'pid': 1991.0,
#    'difficulty': 5}},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/2957',
#    'title': '이진 탐색 트리',
#    'exbank': '백준',
#    'cate1': '중급',
#    'cate2': '2단계',
#    'cate3': '자료구조',
#    'correct_ratio': 0.2298,
#    'pid': 2957.0,
#    'difficulty': 5}},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/5639',
#    'title': '이진 검색 트리',
#    'exbank': '백준',
#    'cate1': '중급',
#    'cate2': '2단계',
#    'cate3': '자료구조',
#    'correct_ratio': 0.432,
#    'pid': 5639.0,
#    'difficulty': 5}},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/3038',
#    'title': '완전 이진 트리',
#    'exbank': '백준',
#    'cate1': '중급',
#    'cate2': '2단계',
#    'cate3': '자료구조',
#    'correct_ratio': 0.596,
#    'pid': 3038.0,
#    'difficulty': 5}},
#  {'fields': {'url': 'https://www.hackerrank.com/challenges/nested-list',
#    'title': 'Nested Lists',
#    'exbank': '해커랭크',
#    'cate1': '초급',
#    'cate2': '3단계',
#    'cate3': 'list',
#    'correct_ratio': 0.898807,
#    'pid': None,
#    'difficulty': 3}},
#  {'fields': {'url': 'https://www.hackerrank.com/challenges/python-lists',
#    'title': 'Lists',
#    'exbank': '해커랭크',
#    'cate1': '초급',
#    'cate2': '3단계',
#    'cate3': 'list',
#    'correct_ratio': 0.895305,
#    'pid': None,
#    'difficulty': 3}},
#  {'fields': {'url': 'https://www.hackerrank.com/challenges/python-tuples',
#    'title': 'Tuples',
#    'exbank': '해커랭크',
#    'cate1': '초급',
#    'cate2': '3단계',
#    'cate3': 'tuple',
#    'correct_ratio': 0.981736,
#    'pid': None,
#    'difficulty': 3}},
#  {'fields': {'url': 'https://www.hackerrank.com/challenges/swap-case',
#    'title': 'sWAP cASE',
#    'exbank': '해커랭크',
#    'cate1': '초급',
#    'cate2': '3단계',
#    'cate3': '문자열 이용',
#    'correct_ratio': 0.985278,
#    'pid': None,
#    'difficulty': 3}},
#  {'fields': {'url': 'https://www.hackerrank.com/challenges/python-string-split-and-join',
#    'title': 'String Split and Join',
#    'exbank': '해커랭크',
#    'cate1': '초급',
#    'cate2': '3단계',
#    'cate3': '문자열 이용',
#    'correct_ratio': 0.987638,
#    'pid': None,
#    'difficulty': 3}},
#  {'fields': {'url': 'https://www.hackerrank.com/challenges/python-mutations',
#    'title': 'Mutations',
#    'exbank': '해커랭크',
#    'cate1': '초급',
#    'cate2': '3단계',
#    'cate3': '문자열 이용',
#    'correct_ratio': 0.98181,
#    'pid': None,
#    'difficulty': 3}},
#  {'fields': {'url': 'https://www.hackerrank.com/challenges/find-a-string',
#    'title': 'Find a string',
#    'exbank': '해커랭크',
#    'cate1': '초급',
#    'cate2': '3단계',
#    'cate3': '문자열 이용',
#    'correct_ratio': 0.936213,
#    'pid': None,
#    'difficulty': 3}},
#  {'fields': {'url': 'https://www.hackerrank.com/challenges/text-wrap',
#    'title': 'Text Wrap',
#    'exbank': '해커랭크',
#    'cate1': '초급',
#    'cate2': '3단계',
#    'cate3': '문자열 이용',
#    'correct_ratio': 0.988032,
#    'pid': None,
#    'difficulty': 3}},
#  {'fields': {'url': 'https://www.hackerrank.com/challenges/capitalize',
#    'title': 'Capitalize!',
#    'exbank': '해커랭크',
#    'cate1': '초급',
#    'cate2': '3단계',
#    'cate3': '문자열 이용',
#    'correct_ratio': 0.821237,
#    'pid': None,
#    'difficulty': 3}},
#  {'fields': {'url': 'https://www.hackerrank.com/challenges/merge-the-tools',
#    'title': 'Merge the Tools!',
#    'exbank': '해커랭크',
#    'cate1': '초급',
#    'cate2': '3단계',
#    'cate3': '문자열 이용',
#    'correct_ratio': 0.926066,
#    'pid': None,
#    'difficulty': 3}},
#  {'fields': {'url': 'https://www.hackerrank.com/challenges/defaultdict-tutorial',
#    'title': 'DefaultDict Tutorial',
#    'exbank': '해커랭크',
#    'cate1': '초급',
#    'cate2': '3단계',
#    'cate3': 'list',
#    'correct_ratio': 0.929442,
#    'pid': None,
#    'difficulty': 3}},
#  {'fields': {'url': 'https://www.hackerrank.com/challenges/most-commons',
#    'title': 'Company Logo',
#    'exbank': '해커랭크',
#    'cate1': '초급',
#    'cate2': '3단계',
#    'cate3': '문자열 이용',
#    'correct_ratio': 0.880709,
#    'pid': None,
#    'difficulty': 3}},
#  {'fields': {'url': 'https://www.hackerrank.com/challenges/standardize-mobile-number-using-decorators',
#    'title': 'Standardize Mobile Number Using Decorators',
#    'exbank': '해커랭크',
#    'cate1': '초급',
#    'cate2': '3단계',
#    'cate3': '문자열 이용',
#    'correct_ratio': 0.977487,
#    'pid': None,
#    'difficulty': 3}},
#  {'fields': {'url': 'https://www.hackerrank.com/challenges/words-score',
#    'title': 'Words Score',
#    'exbank': '해커랭크',
#    'cate1': '초급',
#    'cate2': '3단계',
#    'cate3': 'list',
#    'correct_ratio': 0.954291,
#    'pid': None,
#    'difficulty': 3}},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/1152',
#    'title': '단어의 개수',
#    'exbank': '백준',
#    'cate1': '초급',
#    'cate2': '3단계',
#    'cate3': 'list',
#    'correct_ratio': 0.2426,
#    'pid': 1152.0,
#    'difficulty': 3}},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/2577',
#    'title': '숫자의 개수',
#    'exbank': '백준',
#    'cate1': '초급',
#    'cate2': '3단계',
#    'cate3': 'list',
#    'correct_ratio': 0.6487,
#    'pid': 2577.0,
#    'difficulty': 3}},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/8958',
#    'title': 'OX퀴즈',
#    'exbank': '백준',
#    'cate1': '초급',
#    'cate2': '3단계',
#    'cate3': 'list',
#    'correct_ratio': 0.5626,
#    'pid': 8958.0,
#    'difficulty': 3}},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/2920',
#    'title': '음계',
#    'exbank': '백준',
#    'cate1': '초급',
#    'cate2': '3단계',
#    'cate3': 'list',
#    'correct_ratio': 0.5824,
#    'pid': 2920.0,
#    'difficulty': 3}},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/10039',
#    'title': '평균 점수',
#    'exbank': '백준',
#    'cate1': '초급',
#    'cate2': '3단계',
#    'cate3': 'list',
#    'correct_ratio': 0.7349,
#    'pid': 10039.0,
#    'difficulty': 3}},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/10809',
#    'title': '알파벳 찾기',
#    'exbank': '백준',
#    'cate1': '초급',
#    'cate2': '3단계',
#    'cate3': '문자열 이용',
#    'correct_ratio': 0.5668,
#    'pid': 10809.0,
#    'difficulty': 3}},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/2675',
#    'title': '문자열 반복',
#    'exbank': '백준',
#    'cate1': '초급',
#    'cate2': '3단계',
#    'cate3': '문자열 이용',
#    'correct_ratio': 0.5528,
#    'pid': 2675.0,
#    'difficulty': 3}},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/1157',
#    'title': '단어 공부',
#    'exbank': '백준',
#    'cate1': '초급',
#    'cate2': '3단계',
#    'cate3': '문자열 이용',
#    'correct_ratio': 0.3739,
#    'pid': 1157.0,
#    'difficulty': 3}},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/1316',
#    'title': '그룹 단어 체커',
#    'exbank': '백준',
#    'cate1': '초급',
#    'cate2': '3단계',
#    'cate3': '문자열 이용',
#    'correct_ratio': 0.519,
#    'pid': 1316.0,
#    'difficulty': 3}},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/2908',
#    'title': '상수',
#    'exbank': '백준',
#    'cate1': '초급',
#    'cate2': '3단계',
#    'cate3': '문자열 이용',
#    'correct_ratio': 0.6963,
#    'pid': 2908.0,
#    'difficulty': 3}},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/5622',
#    'title': '다이얼',
#    'exbank': '백준',
#    'cate1': '초급',
#    'cate2': '3단계',
#    'cate3': '문자열 이용',
#    'correct_ratio': 0.5807,
#    'pid': 5622.0,
#    'difficulty': 3}},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/2941',
#    'title': '크로아티아 알파벳',
#    'exbank': '백준',
#    'cate1': '초급',
#    'cate2': '3단계',
#    'cate3': '문자열 이용',
#    'correct_ratio': 0.4738,
#    'pid': 2941.0,
#    'difficulty': 3}},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/10219',
#    'title': 'Meats On The Grill',
#    'exbank': '백준',
#    'cate1': '초급',
#    'cate2': '3단계',
#    'cate3': 'list',
#    'correct_ratio': 0.6189,
#    'pid': 10219.0,
#    'difficulty': 3}},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/1547',
#    'title': '공',
#    'exbank': '백준',
#    'cate1': '초급',
#    'cate2': '3단계',
#    'cate3': 'list',
#    'correct_ratio': 0.7142,
#    'pid': 1547.0,
#    'difficulty': 3}},
#  {'fields': {'url': 'https://www.hackerrank.com/challenges/finding-the-percentage',
#    'title': 'Finding the percentage',
#    'exbank': '해커랭크',
#    'cate1': '중급',
#    'cate2': '1단계',
#    'cate3': 'dictionary',
#    'correct_ratio': 0.971267,
#    'pid': None,
#    'difficulty': 4}},
#  {'fields': {'url': 'https://www.hackerrank.com/challenges/string-validators',
#    'title': 'String Validators',
#    'exbank': '해커랭크',
#    'cate1': '중급',
#    'cate2': '1단계',
#    'cate3': '함수 사용',
#    'correct_ratio': 0.938186,
#    'pid': None,
#    'difficulty': 4}},
#  {'fields': {'url': 'https://www.hackerrank.com/challenges/py-set-add',
#    'title': 'Set .add()',
#    'exbank': '해커랭크',
#    'cate1': '중급',
#    'cate2': '1단계',
#    'cate3': 'set',
#    'correct_ratio': 0.992978,
#    'pid': None,
#    'difficulty': 4}},
#  {'fields': {'url': 'https://www.hackerrank.com/challenges/word-order',
#    'title': 'Word Order',
#    'exbank': '해커랭크',
#    'cate1': '중급',
#    'cate2': '1단계',
#    'cate3': 'dictionary',
#    'correct_ratio': 0.877751,
#    'pid': None,
#    'difficulty': 4}},
#  {'fields': {'url': 'https://www.hackerrank.com/challenges/py-set-discard-remove-pop',
#    'title': 'Set .discard(), .remove() & .pop()',
#    'exbank': '해커랭크',
#    'cate1': '중급',
#    'cate2': '1단계',
#    'cate3': 'set',
#    'correct_ratio': 0.968613,
#    'pid': None,
#    'difficulty': 4}},
#  {'fields': {'url': 'https://www.hackerrank.com/challenges/py-set-union',
#    'title': 'Set .union() Operation',
#    'exbank': '해커랭크',
#    'cate1': '중급',
#    'cate2': '1단계',
#    'cate3': 'set',
#    'correct_ratio': 0.993646,
#    'pid': None,
#    'difficulty': 4}},
#  {'fields': {'url': 'https://www.hackerrank.com/challenges/py-set-intersection-operation',
#    'title': 'Set .intersection() Operation',
#    'exbank': '해커랭크',
#    'cate1': '중급',
#    'cate2': '1단계',
#    'cate3': 'set',
#    'correct_ratio': 0.995489,
#    'pid': None,
#    'difficulty': 4}},
#  {'fields': {'url': 'https://www.hackerrank.com/challenges/python-power-mod-power',
#    'title': 'Power - Mod Power',
#    'exbank': '해커랭크',
#    'cate1': '중급',
#    'cate2': '1단계',
#    'cate3': '함수 사용',
#    'correct_ratio': 0.99256,
#    'pid': None,
#    'difficulty': 4}},
#  {'fields': {'url': 'https://www.hackerrank.com/challenges/py-set-difference-operation',
#    'title': 'Set .difference() Operation',
#    'exbank': '해커랭크',
#    'cate1': '중급',
#    'cate2': '1단계',
#    'cate3': 'set',
#    'correct_ratio': 0.994637,
#    'pid': None,
#    'difficulty': 4}},
#  {'fields': {'url': 'https://www.hackerrank.com/challenges/py-set-symmetric-difference-operation',
#    'title': 'Set .symmetric_difference() Operation',
#    'exbank': '해커랭크',
#    'cate1': '중급',
#    'cate2': '1단계',
#    'cate3': 'set',
#    'correct_ratio': 0.996552,
#    'pid': None,
#    'difficulty': 4}},
#  {'fields': {'url': 'https://www.hackerrank.com/challenges/py-set-mutations',
#    'title': 'Set Mutations',
#    'exbank': '해커랭크',
#    'cate1': '중급',
#    'cate2': '1단계',
#    'cate3': 'set',
#    'correct_ratio': 0.984463,
#    'pid': None,
#    'difficulty': 4}},
#  {'fields': {'url': 'https://www.hackerrank.com/challenges/py-the-captains-room',
#    'title': "The Captain's Room",
#    'exbank': '해커랭크',
#    'cate1': '중급',
#    'cate2': '1단계',
#    'cate3': 'set',
#    'correct_ratio': 0.904113,
#    'pid': None,
#    'difficulty': 4}},
#  {'fields': {'url': 'https://www.hackerrank.com/challenges/zipped',
#    'title': 'Zipped!',
#    'exbank': '해커랭크',
#    'cate1': '중급',
#    'cate2': '1단계',
#    'cate3': '함수 사용',
#    'correct_ratio': 0.97752,
#    'pid': None,
#    'difficulty': 4}},
#  {'fields': {'url': 'https://www.hackerrank.com/challenges/python-eval',
#    'title': 'Python Evaluation',
#    'exbank': '해커랭크',
#    'cate1': '중급',
#    'cate2': '1단계',
#    'cate3': '함수 사용',
#    'correct_ratio': 0.972603,
#    'pid': None,
#    'difficulty': 4}},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/1065',
#    'title': '한수',
#    'exbank': '백준',
#    'cate1': '중급',
#    'cate2': '1단계',
#    'cate3': '함수 사용',
#    'correct_ratio': 0.4553,
#    'pid': 1065.0,
#    'difficulty': 4}},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/11654',
#    'title': '아스키 코드',
#    'exbank': '백준',
#    'cate1': '중급',
#    'cate2': '1단계',
#    'cate3': '함수 사용',
#    'correct_ratio': 0.8309,
#    'pid': 11654.0,
#    'difficulty': 4}},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/1978',
#    'title': '소수 찾기',
#    'exbank': '백준',
#    'cate1': '중급',
#    'cate2': '1단계',
#    'cate3': '함수 사용',
#    'correct_ratio': 0.4919,
#    'pid': 1978.0,
#    'difficulty': 4}},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/2581',
#    'title': '소수',
#    'exbank': '백준',
#    'cate1': '중급',
#    'cate2': '1단계',
#    'cate3': '함수 사용',
#    'correct_ratio': 0.3763,
#    'pid': 2581.0,
#    'difficulty': 4}},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/2748',
#    'title': '피보나치 수 2',
#    'exbank': '백준',
#    'cate1': '중급',
#    'cate2': '1단계',
#    'cate3': '함수 사용',
#    'correct_ratio': 0.4165,
#    'pid': 2748.0,
#    'difficulty': 4}},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/11050',
#    'title': '이항 계수 1',
#    'exbank': '백준',
#    'cate1': '중급',
#    'cate2': '1단계',
#    'cate3': '함수 사용',
#    'correct_ratio': 0.6435,
#    'pid': 11050.0,
#    'difficulty': 4}},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/10872',
#    'title': '팩토리얼',
#    'exbank': '백준',
#    'cate1': '중급',
#    'cate2': '1단계',
#    'cate3': '함수 사용',
#    'correct_ratio': 0.6197,
#    'pid': 10872.0,
#    'difficulty': 4}},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/9375',
#    'title': '패션왕 신해빈',
#    'exbank': '백준',
#    'cate1': '중급',
#    'cate2': '1단계',
#    'cate3': 'dictionary',
#    'correct_ratio': 0.5306,
#    'pid': 9375.0,
#    'difficulty': 4}},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/1934',
#    'title': '최소공배수',
#    'exbank': '백준',
#    'cate1': '중급',
#    'cate2': '1단계',
#    'cate3': '함수 사용',
#    'correct_ratio': 0.588,
#    'pid': 1934.0,
#    'difficulty': 4}},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/13241',
#    'title': '최소공배수',
#    'exbank': '백준',
#    'cate1': '중급',
#    'cate2': '1단계',
#    'cate3': '함수 사용',
#    'correct_ratio': 0.6309,
#    'pid': 13241.0,
#    'difficulty': 4}},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/2609',
#    'title': '최대공약수와 최소공배수',
#    'exbank': '백준',
#    'cate1': '중급',
#    'cate2': '1단계',
#    'cate3': '함수 사용',
#    'correct_ratio': 0.6649,
#    'pid': 2609.0,
#    'difficulty': 4}},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/1850',
#    'title': '최대공약수',
#    'exbank': '백준',
#    'cate1': '중급',
#    'cate2': '1단계',
#    'cate3': '함수 사용',
#    'correct_ratio': 0.277,
#    'pid': 1850.0,
#    'difficulty': 4}},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/3036',
#    'title': '링',
#    'exbank': '백준',
#    'cate1': '중급',
#    'cate2': '1단계',
#    'cate3': '함수 사용',
#    'correct_ratio': 0.8208,
#    'pid': 3036.0,
#    'difficulty': 4}},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/10253',
#    'title': '헨리',
#    'exbank': '백준',
#    'cate1': '중급',
#    'cate2': '1단계',
#    'cate3': '함수 사용',
#    'correct_ratio': 0.2855,
#    'pid': 10253.0,
#    'difficulty': 4}},
#  {'fields': {'url': 'https://www.hackerrank.com/challenges/designer-door-mat',
#    'title': 'Designer Door Mat',
#    'exbank': '해커랭크',
#    'cate1': '고급',
#    'cate2': '2단계',
#    'cate3': '기타',
#    'correct_ratio': 0.982432,
#    'pid': None,
#    'difficulty': 8}},
#  {'fields': {'url': 'https://www.hackerrank.com/challenges/python-string-formatting',
#    'title': 'String Formatting',
#    'exbank': '해커랭크',
#    'cate1': '고급',
#    'cate2': '2단계',
#    'cate3': '기타',
#    'correct_ratio': 0.915458,
#    'pid': None,
#    'difficulty': 8}},
#  {'fields': {'url': 'https://www.hackerrank.com/challenges/python-sort-sort',
#    'title': 'Athlete Sort',
#    'exbank': '해커랭크',
#    'cate1': '고급',
#    'cate2': '2단계',
#    'cate3': '기타',
#    'correct_ratio': 0.961567,
#    'pid': None,
#    'difficulty': 8}},
#  {'fields': {'url': 'https://www.hackerrank.com/challenges/introduction-to-regex',
#    'title': 'Detect Floating Point Number',
#    'exbank': '해커랭크',
#    'cate1': '고급',
#    'cate2': '2단계',
#    'cate3': '정규표현식',
#    'correct_ratio': 0.917035,
#    'pid': None,
#    'difficulty': 8}},
#  {'fields': {'url': 'https://www.hackerrank.com/challenges/re-split',
#    'title': 'Re.split()',
#    'exbank': '해커랭크',
#    'cate1': '고급',
#    'cate2': '2단계',
#    'cate3': '정규표현식',
#    'correct_ratio': 0.939759,
#    'pid': None,
#    'difficulty': 8}},
#  {'fields': {'url': 'https://www.hackerrank.com/challenges/validate-list-of-email-address-with-filter',
#    'title': 'Validating Email Addresses With a Filter',
#    'exbank': '해커랭크',
#    'cate1': '고급',
#    'cate2': '2단계',
#    'cate3': '정규표현식',
#    'correct_ratio': 0.880835,
#    'pid': None,
#    'difficulty': 8}},
#  {'fields': {'url': 'https://www.hackerrank.com/challenges/re-group-groups',
#    'title': 'Group(), Groups() & Groupdict()',
#    'exbank': '해커랭크',
#    'cate1': '고급',
#    'cate2': '2단계',
#    'cate3': '정규표현식',
#    'correct_ratio': 0.926869,
#    'pid': None,
#    'difficulty': 8}},
#  {'fields': {'url': 'https://www.hackerrank.com/challenges/re-findall-re-finditer',
#    'title': 'Re.findall() & Re.finditer()',
#    'exbank': '해커랭크',
#    'cate1': '고급',
#    'cate2': '2단계',
#    'cate3': '정규표현식',
#    'correct_ratio': 0.889458,
#    'pid': None,
#    'difficulty': 8}},
#  {'fields': {'url': 'https://www.hackerrank.com/challenges/re-start-re-end',
#    'title': 'Re.start() & Re.end()',
#    'exbank': '해커랭크',
#    'cate1': '고급',
#    'cate2': '2단계',
#    'cate3': '정규표현식',
#    'correct_ratio': 0.952184,
#    'pid': None,
#    'difficulty': 8}},
#  {'fields': {'url': 'https://www.hackerrank.com/challenges/re-sub-regex-substitution',
#    'title': 'Regex Substitution',
#    'exbank': '해커랭크',
#    'cate1': '고급',
#    'cate2': '2단계',
#    'cate3': '정규표현식',
#    'correct_ratio': 0.923924,
#    'pid': None,
#    'difficulty': 8}},
#  {'fields': {'url': 'https://www.hackerrank.com/challenges/validate-a-roman-number',
#    'title': 'Validating Roman Numerals',
#    'exbank': '해커랭크',
#    'cate1': '고급',
#    'cate2': '2단계',
#    'cate3': '정규표현식',
#    'correct_ratio': 0.903711,
#    'pid': None,
#    'difficulty': 8}},
#  {'fields': {'url': 'https://www.hackerrank.com/challenges/validating-the-phone-number',
#    'title': 'Validating phone numbers',
#    'exbank': '해커랭크',
#    'cate1': '고급',
#    'cate2': '2단계',
#    'cate3': '정규표현식',
#    'correct_ratio': 0.960728,
#    'pid': None,
#    'difficulty': 8}},
#  {'fields': {'url': 'https://www.hackerrank.com/challenges/validating-named-email-addresses',
#    'title': 'Validating and Parsing Email Addresses',
#    'exbank': '해커랭크',
#    'cate1': '고급',
#    'cate2': '2단계',
#    'cate3': '정규표현식',
#    'correct_ratio': 0.887828,
#    'pid': None,
#    'difficulty': 8}},
#  {'fields': {'url': 'https://www.hackerrank.com/challenges/hex-color-code',
#    'title': 'Hex Color Code',
#    'exbank': '해커랭크',
#    'cate1': '고급',
#    'cate2': '2단계',
#    'cate3': '정규표현식',
#    'correct_ratio': 0.96435,
#    'pid': None,
#    'difficulty': 8}},
#  {'fields': {'url': 'https://www.hackerrank.com/challenges/html-parser-part-1',
#    'title': 'HTML Parser - Part 1',
#    'exbank': '해커랭크',
#    'cate1': '고급',
#    'cate2': '2단계',
#    'cate3': '기타',
#    'correct_ratio': 0.9479,
#    'pid': None,
#    'difficulty': 8}},
#  {'fields': {'url': 'https://www.hackerrank.com/challenges/html-parser-part-2',
#    'title': 'HTML Parser - Part 2',
#    'exbank': '해커랭크',
#    'cate1': '고급',
#    'cate2': '2단계',
#    'cate3': '기타',
#    'correct_ratio': 0.98318,
#    'pid': None,
#    'difficulty': 8}},
#  {'fields': {'url': 'https://www.hackerrank.com/challenges/detect-html-tags-attributes-and-attribute-values',
#    'title': 'Detect HTML Tags, Attributes and Attribute Values',
#    'exbank': '해커랭크',
#    'cate1': '고급',
#    'cate2': '2단계',
#    'cate3': '기타',
#    'correct_ratio': 0.978141,
#    'pid': None,
#    'difficulty': 8}},
#  {'fields': {'url': 'https://www.hackerrank.com/challenges/xml-1-find-the-score',
#    'title': 'XML 1 - Find the Score',
#    'exbank': '해커랭크',
#    'cate1': '고급',
#    'cate2': '2단계',
#    'cate3': '기타',
#    'correct_ratio': 0.975546,
#    'pid': None,
#    'difficulty': 8}},
#  {'fields': {'url': 'https://www.hackerrank.com/challenges/validating-uid',
#    'title': 'Validating UID',
#    'exbank': '해커랭크',
#    'cate1': '고급',
#    'cate2': '2단계',
#    'cate3': '정규표현식',
#    'correct_ratio': 0.95829,
#    'pid': None,
#    'difficulty': 8}},
#  {'fields': {'url': 'https://www.hackerrank.com/challenges/validating-credit-card-number',
#    'title': 'Validating Credit Card Numbers',
#    'exbank': '해커랭크',
#    'cate1': '고급',
#    'cate2': '2단계',
#    'cate3': '정규표현식',
#    'correct_ratio': 0.951983,
#    'pid': None,
#    'difficulty': 8}},
#  {'fields': {'url': 'https://www.hackerrank.com/challenges/xml2-find-the-maximum-depth',
#    'title': 'XML2 - Find the Maximum Depth',
#    'exbank': '해커랭크',
#    'cate1': '고급',
#    'cate2': '2단계',
#    'cate3': '기타',
#    'correct_ratio': 0.968081,
#    'pid': None,
#    'difficulty': 8}},
#  {'fields': {'url': 'https://www.hackerrank.com/challenges/validating-postalcode',
#    'title': 'Validating Postal Codes',
#    'exbank': '해커랭크',
#    'cate1': '고급',
#    'cate2': '2단계',
#    'cate3': '정규표현식',
#    'correct_ratio': 0.851728,
#    'pid': None,
#    'difficulty': 8}},
#  {'fields': {'url': 'https://www.hackerrank.com/challenges/matrix-script',
#    'title': 'Matrix Script',
#    'exbank': '해커랭크',
#    'cate1': '고급',
#    'cate2': '2단계',
#    'cate3': '정규표현식',
#    'correct_ratio': 0.87796,
#    'pid': None,
#    'difficulty': 8}},
#  {'fields': {'url': 'https://www.hackerrank.com/challenges/np-arrays',
#    'title': 'Arrays',
#    'exbank': '해커랭크',
#    'cate1': '고급',
#    'cate2': '2단계',
#    'cate3': '기타',
#    'correct_ratio': 0.958109,
#    'pid': None,
#    'difficulty': 8}},
#  {'fields': {'url': 'https://www.hackerrank.com/challenges/np-shape-reshape',
#    'title': 'Shape and Reshape',
#    'exbank': '해커랭크',
#    'cate1': '고급',
#    'cate2': '2단계',
#    'cate3': '기타',
#    'correct_ratio': 0.962802,
#    'pid': None,
#    'difficulty': 8}},
#  {'fields': {'url': 'https://www.hackerrank.com/challenges/np-transpose-and-flatten',
#    'title': 'Transpose and Flatten',
#    'exbank': '해커랭크',
#    'cate1': '고급',
#    'cate2': '2단계',
#    'cate3': '기타',
#    'correct_ratio': 0.969415,
#    'pid': None,
#    'difficulty': 8}},
#  {'fields': {'url': 'https://www.hackerrank.com/challenges/np-concatenate',
#    'title': 'Concatenate',
#    'exbank': '해커랭크',
#    'cate1': '고급',
#    'cate2': '2단계',
#    'cate3': '기타',
#    'correct_ratio': 0.990601,
#    'pid': None,
#    'difficulty': 8}},
#  {'fields': {'url': 'https://www.hackerrank.com/challenges/np-zeros-and-ones',
#    'title': 'Zeros and Ones',
#    'exbank': '해커랭크',
#    'cate1': '고급',
#    'cate2': '2단계',
#    'cate3': '기타',
#    'correct_ratio': 0.946406,
#    'pid': None,
#    'difficulty': 8}},
#  {'fields': {'url': 'https://www.hackerrank.com/challenges/np-eye-and-identity',
#    'title': 'Eye and Identity',
#    'exbank': '해커랭크',
#    'cate1': '고급',
#    'cate2': '2단계',
#    'cate3': '기타',
#    'correct_ratio': 0.941737,
#    'pid': None,
#    'difficulty': 8}},
#  {'fields': {'url': 'https://www.hackerrank.com/challenges/np-array-mathematics',
#    'title': 'Array Mathematics',
#    'exbank': '해커랭크',
#    'cate1': '고급',
#    'cate2': '2단계',
#    'cate3': '기타',
#    'correct_ratio': 0.947421,
#    'pid': None,
#    'difficulty': 8}},
#  {'fields': {'url': 'https://www.hackerrank.com/challenges/floor-ceil-and-rint',
#    'title': 'Floor, Ceil and Rint',
#    'exbank': '해커랭크',
#    'cate1': '고급',
#    'cate2': '2단계',
#    'cate3': '기타',
#    'correct_ratio': 0.963759,
#    'pid': None,
#    'difficulty': 8}},
#  {'fields': {'url': 'https://www.hackerrank.com/challenges/np-sum-and-prod',
#    'title': 'Sum and Prod',
#    'exbank': '해커랭크',
#    'cate1': '고급',
#    'cate2': '2단계',
#    'cate3': '기타',
#    'correct_ratio': 0.983712,
#    'pid': None,
#    'difficulty': 8}},
#  {'fields': {'url': 'https://www.hackerrank.com/challenges/np-min-and-max',
#    'title': 'Min and Max',
#    'exbank': '해커랭크',
#    'cate1': '고급',
#    'cate2': '2단계',
#    'cate3': '기타',
#    'correct_ratio': 0.986357,
#    'pid': None,
#    'difficulty': 8}},
#  {'fields': {'url': 'https://www.hackerrank.com/challenges/np-mean-var-and-std',
#    'title': 'Mean, Var, and Std',
#    'exbank': '해커랭크',
#    'cate1': '고급',
#    'cate2': '2단계',
#    'cate3': '기타',
#    'correct_ratio': 0.948152,
#    'pid': None,
#    'difficulty': 8}},
#  {'fields': {'url': 'https://www.hackerrank.com/challenges/np-dot-and-cross',
#    'title': 'Dot and Cross',
#    'exbank': '해커랭크',
#    'cate1': '고급',
#    'cate2': '2단계',
#    'cate3': '기타',
#    'correct_ratio': 0.988531,
#    'pid': None,
#    'difficulty': 8}},
#  {'fields': {'url': 'https://www.hackerrank.com/challenges/np-inner-and-outer',
#    'title': 'Inner and Outer',
#    'exbank': '해커랭크',
#    'cate1': '고급',
#    'cate2': '2단계',
#    'cate3': '기타',
#    'correct_ratio': 0.985111,
#    'pid': None,
#    'difficulty': 8}},
#  {'fields': {'url': 'https://www.hackerrank.com/challenges/np-polynomials',
# ...
#    'cate2': '2단계',
#    'cate3': 'dfs/bfs',
#    'correct_ratio': 0.2673,
#    'pid': 2250.0,
#    'difficulty': 8}},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/1967',
#    'title': '트리의 지름',
#    'exbank': '백준',
#    'cate1': '고급',
#    'cate2': '2단계',
#    'cate3': 'dfs/bfs',
#    'correct_ratio': 0.4632,
#    'pid': 1967.0,
#    'difficulty': 8}},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/1289',
#    'title': '트리의 가중치',
#    'exbank': '백준',
#    'cate1': '고급',
#    'cate2': '2단계',
#    'cate3': 'dfs/bfs',
#    'correct_ratio': 0.2976,
#    'pid': 1289.0,
#    'difficulty': 8}},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/7576',
#    'title': '토마토',
#    'exbank': '백준',
#    'cate1': '고급',
#    'cate2': '2단계',
#    'cate3': 'dfs/bfs',
#    'correct_ratio': 0.2955,
#    'pid': 7576.0,
#    'difficulty': 8}},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/7569',
#    'title': '토마토',
#    'exbank': '백준',
#    'cate1': '고급',
#    'cate2': '2단계',
#    'cate3': 'dfs/bfs',
#    'correct_ratio': 0.358,
#    'pid': 7569.0,
#    'difficulty': 8}},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/2178',
#    'title': '미로 탐색',
#    'exbank': '백준',
#    'cate1': '고급',
#    'cate2': '2단계',
#    'cate3': 'dfs/bfs',
#    'correct_ratio': 0.3339,
#    'pid': 2178.0,
#    'difficulty': 8}},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/2606',
#    'title': '바이러스',
#    'exbank': '백준',
#    'cate1': '고급',
#    'cate2': '2단계',
#    'cate3': 'dfs/bfs',
#    'correct_ratio': 0.4059,
#    'pid': 2606.0,
#    'difficulty': 8}},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/2667',
#    'title': '단지호붙이기',
#    'exbank': '백준',
#    'cate1': '고급',
#    'cate2': '2단계',
#    'cate3': 'dfs/bfs',
#    'correct_ratio': 0.3825,
#    'pid': 2667.0,
#    'difficulty': 8}},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/10216',
#    'title': 'Count Circle Groups',
#    'exbank': '백준',
#    'cate1': '고급',
#    'cate2': '2단계',
#    'cate3': 'dfs/bfs',
#    'correct_ratio': 0.2735,
#    'pid': 10216.0,
#    'difficulty': 8}},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/1890',
#    'title': '점프',
#    'exbank': '백준',
#    'cate1': '고급',
#    'cate2': '2단계',
#    'cate3': 'dfs/bfs',
#    'correct_ratio': 0.2691,
#    'pid': 1890.0,
#    'difficulty': 8}},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/1325',
#    'title': '효율적인 해킹',
#    'exbank': '백준',
#    'cate1': '고급',
#    'cate2': '2단계',
#    'cate3': 'dfs/bfs',
#    'correct_ratio': 0.2171,
#    'pid': 1325.0,
#    'difficulty': 8}},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/10451',
#    'title': '순열 사이클',
#    'exbank': '백준',
#    'cate1': '고급',
#    'cate2': '2단계',
#    'cate3': 'dfs/bfs',
#    'correct_ratio': 0.6311,
#    'pid': 10451.0,
#    'difficulty': 8}},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/1931',
#    'title': '회의실배정',
#    'exbank': '백준',
#    'cate1': '고급',
#    'cate2': '2단계',
#    'cate3': 'greedy algorithm',
#    'correct_ratio': 0.2946,
#    'pid': 1931.0,
#    'difficulty': 8}},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/11047',
#    'title': '동전 0',
#    'exbank': '백준',
#    'cate1': '고급',
#    'cate2': '2단계',
#    'cate3': 'greedy algorithm',
#    'correct_ratio': 0.5853,
#    'pid': 11047.0,
#    'difficulty': 8}},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/11399',
#    'title': 'ATM',
#    'exbank': '백준',
#    'cate1': '고급',
#    'cate2': '2단계',
#    'cate3': 'greedy algorithm',
#    'correct_ratio': 0.7068,
#    'pid': 11399.0,
#    'difficulty': 8}},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/2217',
#    'title': '로프',
#    'exbank': '백준',
#    'cate1': '고급',
#    'cate2': '2단계',
#    'cate3': 'greedy algorithm',
#    'correct_ratio': 0.4754,
#    'pid': 2217.0,
#    'difficulty': 8}},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/4307',
#    'title': '개미',
#    'exbank': '백준',
#    'cate1': '고급',
#    'cate2': '2단계',
#    'cate3': 'greedy algorithm',
#    'correct_ratio': 0.481,
#    'pid': 4307.0,
#    'difficulty': 8}},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/9663',
#    'title': 'N-Queen',
#    'exbank': '백준',
#    'cate1': '고급',
#    'cate2': '2단계',
#    'cate3': 'backtracking',
#    'correct_ratio': 0.5724,
#    'pid': 9663.0,
#    'difficulty': 8}},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/2580',
#    'title': '스도쿠',
#    'exbank': '백준',
#    'cate1': '고급',
#    'cate2': '2단계',
#    'cate3': 'backtracking',
#    'correct_ratio': 0.3252,
#    'pid': 2580.0,
#    'difficulty': 8}},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/2661',
#    'title': '좋은수열',
#    'exbank': '백준',
#    'cate1': '고급',
#    'cate2': '2단계',
#    'cate3': 'backtracking',
#    'correct_ratio': 0.5628,
#    'pid': 2661.0,
#    'difficulty': 8}},
#  {'fields': {'url': 'https://www.hackerrank.com/challenges/exceptions',
#    'title': 'Exceptions',
#    'exbank': '해커랭크',
#    'cate1': '고급',
#    'cate2': '1단계',
#    'cate3': '예외 처리',
#    'correct_ratio': 0.963788,
#    'pid': None,
#    'difficulty': 7}},
#  {'fields': {'url': 'https://www.hackerrank.com/challenges/incorrect-regex',
#    'title': 'Incorrect Regex',
#    'exbank': '해커랭크',
#    'cate1': '고급',
#    'cate2': '1단계',
#    'cate3': '예외 처리',
#    'correct_ratio': 0.979607,
#    'pid': None,
#    'difficulty': 7}},
#  {'fields': {'url': 'https://www.hackerrank.com/challenges/class-1-dealing-with-complex-numbers',
#    'title': 'Classes: Dealing with Complex Numbers',
#    'exbank': '해커랭크',
#    'cate1': '고급',
#    'cate2': '1단계',
#    'cate3': '객체 지향적 사고',
#    'correct_ratio': 0.912321,
#    'pid': None,
#    'difficulty': 7}},
#  {'fields': {'url': 'https://www.hackerrank.com/challenges/class-2-find-the-torsional-angle',
#    'title': 'Class 2 - Find the Torsional Angle',
#    'exbank': '해커랭크',
#    'cate1': '고급',
#    'cate2': '1단계',
#    'cate3': '객체 지향적 사고',
#    'correct_ratio': 0.972841,
#    'pid': None,
#    'difficulty': 7}},
#  {'fields': {'url': 'https://www.hackerrank.com/challenges/default-arguments',
#    'title': 'Default Arguments',
#    'exbank': '해커랭크',
#    'cate1': '고급',
#    'cate2': '1단계',
#    'cate3': '객체 지향적 사고',
#    'correct_ratio': 0.80641,
#    'pid': None,
#    'difficulty': 7}},
#  {'fields': {'url': 'https://www.hackerrank.com/challenges/ginorts',
#    'title': 'ginortS',
#    'exbank': '해커랭크',
#    'cate1': '중급',
#    'cate2': '3단계',
#    'cate3': 'Sorting',
#    'correct_ratio': 0.964414,
#    'pid': None,
#    'difficulty': 6}},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/2750',
#    'title': '수 정렬하기',
#    'exbank': '백준',
#    'cate1': '중급',
#    'cate2': '3단계',
#    'cate3': 'Sorting',
#    'correct_ratio': 0.5857,
#    'pid': 2750.0,
#    'difficulty': 6}},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/2751',
#    'title': '수 정렬하기 2',
#    'exbank': '백준',
#    'cate1': '중급',
#    'cate2': '3단계',
#    'cate3': 'Sorting',
#    'correct_ratio': 0.3276,
#    'pid': 2751.0,
#    'difficulty': 6}},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/10989',
#    'title': '수 정렬하기 3',
#    'exbank': '백준',
#    'cate1': '중급',
#    'cate2': '3단계',
#    'cate3': 'Sorting',
#    'correct_ratio': 0.2334,
#    'pid': 10989.0,
#    'difficulty': 6}},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/2108',
#    'title': '통계학',
#    'exbank': '백준',
#    'cate1': '중급',
#    'cate2': '3단계',
#    'cate3': 'Sorting',
#    'correct_ratio': 0.2699,
#    'pid': 2108.0,
#    'difficulty': 6}},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/1427',
#    'title': '소트인사이드',
#    'exbank': '백준',
#    'cate1': '중급',
#    'cate2': '3단계',
#    'cate3': 'Sorting',
#    'correct_ratio': 0.5999,
#    'pid': 1427.0,
#    'difficulty': 6}},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/1181',
#    'title': '단어 정렬',
#    'exbank': '백준',
#    'cate1': '중급',
#    'cate2': '3단계',
#    'cate3': 'Sorting',
#    'correct_ratio': 0.3727,
#    'pid': 1181.0,
#    'difficulty': 6}},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/1920',
#    'title': '수 찾기',
#    'exbank': '백준',
#    'cate1': '중급',
#    'cate2': '3단계',
#    'cate3': 'Searching',
#    'correct_ratio': 0.2754,
#    'pid': 1920.0,
#    'difficulty': 6}},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/1654',
#    'title': '랜선 자르기',
#    'exbank': '백준',
#    'cate1': '중급',
#    'cate2': '3단계',
#    'cate3': 'Searching',
#    'correct_ratio': 0.1867,
#    'pid': 1654.0,
#    'difficulty': 6}},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/10815',
#    'title': '숫자 카드',
#    'exbank': '백준',
#    'cate1': '중급',
#    'cate2': '3단계',
#    'cate3': 'Searching',
#    'correct_ratio': 0.4702,
#    'pid': 10815.0,
#    'difficulty': 6}},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/1300',
#    'title': 'K째 수',
#    'exbank': '백준',
#    'cate1': '중급',
#    'cate2': '3단계',
#    'cate3': 'Searching',
#    'correct_ratio': 0.364,
#    'pid': 1300.0,
#    'difficulty': 6}},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/1003',
#    'title': '피보나치 함수',
#    'exbank': '백준',
#    'cate1': '고급',
#    'cate2': '3단계',
#    'cate3': '동적 프로그래밍',
#    'correct_ratio': 0.2913,
#    'pid': 1003.0,
#    'difficulty': 9}},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/11051',
#    'title': '이항 계수 2',
#    'exbank': '백준',
#    'cate1': '고급',
#    'cate2': '3단계',
#    'cate3': '동적 프로그래밍',
#    'correct_ratio': 0.3837,
#    'pid': 11051.0,
#    'difficulty': 9}},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/2407',
#    'title': '조합',
#    'exbank': '백준',
#    'cate1': '고급',
#    'cate2': '3단계',
#    'cate3': '동적 프로그래밍',
#    'correct_ratio': 0.3264,
#    'pid': 2407.0,
#    'difficulty': 9}},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/1149',
#    'title': 'RGB거리',
#    'exbank': '백준',
#    'cate1': '고급',
#    'cate2': '3단계',
#    'cate3': '동적 프로그래밍',
#    'correct_ratio': 0.4646,
#    'pid': 1149.0,
#    'difficulty': 9}},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/1932',
#    'title': '정수 삼각형',
#    'exbank': '백준',
#    'cate1': '고급',
#    'cate2': '3단계',
#    'cate3': '동적 프로그래밍',
#    'correct_ratio': 0.5777,
#    'pid': 1932.0,
#    'difficulty': 9}},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/2579',
#    'title': '계단 오르기',
#    'exbank': '백준',
#    'cate1': '고급',
#    'cate2': '3단계',
#    'cate3': '동적 프로그래밍',
#    'correct_ratio': 0.3892,
#    'pid': 2579.0,
#    'difficulty': 9}},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/1463',
#    'title': '1로 만들기',
#    'exbank': '백준',
#    'cate1': '고급',
#    'cate2': '3단계',
#    'cate3': '동적 프로그래밍',
#    'correct_ratio': 0.3206,
#    'pid': 1463.0,
#    'difficulty': 9}},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/1005',
#    'title': 'ACM Craft',
#    'exbank': '백준',
#    'cate1': '고급',
#    'cate2': '3단계',
#    'cate3': '동적 프로그래밍',
#    'correct_ratio': 0.182,
#    'pid': 1005.0,
#    'difficulty': 9}},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/10844',
#    'title': '쉬운 계단 수',
#    'exbank': '백준',
#    'cate1': '고급',
#    'cate2': '3단계',
#    'cate3': '동적 프로그래밍',
#    'correct_ratio': 0.2846,
#    'pid': 10844.0,
#    'difficulty': 9}},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/2293',
#    'title': '동전 1',
#    'exbank': '백준',
#    'cate1': '고급',
#    'cate2': '3단계',
#    'cate3': '동적 프로그래밍',
#    'correct_ratio': 0.4157,
#    'pid': 2293.0,
#    'difficulty': 9}},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/2156',
#    'title': '포도주 시식',
#    'exbank': '백준',
#    'cate1': '고급',
#    'cate2': '3단계',
#    'cate3': '동적 프로그래밍',
#    'correct_ratio': 0.3438,
#    'pid': 2156.0,
#    'difficulty': 9}},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/1520',
#    'title': '내리막 길',
#    'exbank': '백준',
#    'cate1': '고급',
#    'cate2': '3단계',
#    'cate3': '동적 프로그래밍',
#    'correct_ratio': 0.2671,
#    'pid': 1520.0,
#    'difficulty': 9}},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/9251',
#    'title': 'LCS',
#    'exbank': '백준',
#    'cate1': '고급',
#    'cate2': '3단계',
#    'cate3': '동적 프로그래밍',
#    'correct_ratio': 0.4197,
#    'pid': 9251.0,
#    'difficulty': 9}},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/11066',
#    'title': '파일 합치기',
#    'exbank': '백준',
#    'cate1': '고급',
#    'cate2': '3단계',
#    'cate3': '동적 프로그래밍',
#    'correct_ratio': 0.5207,
#    'pid': 11066.0,
#    'difficulty': 9}},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/1912',
#    'title': '연속합',
#    'exbank': '백준',
#    'cate1': '고급',
#    'cate2': '3단계',
#    'cate3': '동적 프로그래밍',
#    'correct_ratio': 0.27,
#    'pid': 1912.0,
#    'difficulty': 9}},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/9461',
#    'title': '파도반 수열',
#    'exbank': '백준',
#    'cate1': '고급',
#    'cate2': '3단계',
#    'cate3': '동적 프로그래밍',
#    'correct_ratio': 0.3832,
#    'pid': 9461.0,
#    'difficulty': 9}},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/9252',
#    'title': 'LCS 2',
#    'exbank': '백준',
#    'cate1': '고급',
#    'cate2': '3단계',
#    'cate3': '동적 프로그래밍',
#    'correct_ratio': 0.4169,
#    'pid': 9252.0,
#    'difficulty': 9}},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/1693',
#    'title': '트리 색칠하기',
#    'exbank': '백준',
#    'cate1': '고급',
#    'cate2': '3단계',
#    'cate3': '동적 프로그래밍',
#    'correct_ratio': 0.2495,
#    'pid': 1693.0,
#    'difficulty': 9}},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/2098',
#    'title': '외판원 순회',
#    'exbank': '백준',
#    'cate1': '고급',
#    'cate2': '3단계',
#    'cate3': '동적 프로그래밍',
#    'correct_ratio': 0.2605,
#    'pid': 2098.0,
#    'difficulty': 9}},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/2618',
#    'title': '경찰차',
#    'exbank': '백준',
#    'cate1': '고급',
#    'cate2': '3단계',
#    'cate3': '동적 프로그래밍',
#    'correct_ratio': 0.2919,
#    'pid': 2618.0,
#    'difficulty': 9}},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/1315',
#    'title': 'RPG',
#    'exbank': '백준',
#    'cate1': '고급',
#    'cate2': '3단계',
#    'cate3': '동적 프로그래밍',
#    'correct_ratio': 0.1908,
#    'pid': 1315.0,
#    'difficulty': 9}},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/11062',
#    'title': '카드 게임',
#    'exbank': '백준',
#    'cate1': '고급',
#    'cate2': '3단계',
#    'cate3': '동적 프로그래밍',
#    'correct_ratio': 0.4369,
#    'pid': 11062.0,
#    'difficulty': 9}},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/1562',
#    'title': '계단 수',
#    'exbank': '백준',
#    'cate1': '고급',
#    'cate2': '3단계',
#    'cate3': '동적 프로그래밍',
#    'correct_ratio': 0.4527,
#    'pid': 1562.0,
#    'difficulty': 9}},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/2342',
#    'title': 'Dance Dance Revolution',
#    'exbank': '백준',
#    'cate1': '고급',
#    'cate2': '3단계',
#    'cate3': '동적 프로그래밍',
#    'correct_ratio': 0.3286,
#    'pid': 2342.0,
#    'difficulty': 9}},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/2449',
#    'title': '전구',
#    'exbank': '백준',
#    'cate1': '고급',
#    'cate2': '3단계',
#    'cate3': '동적 프로그래밍',
#    'correct_ratio': 0.4056,
#    'pid': 2449.0,
#    'difficulty': 9}},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/10272',
#    'title': '현상금 사냥꾼 김정은',
#    'exbank': '백준',
#    'cate1': '고급',
#    'cate2': '3단계',
#    'cate3': '동적 프로그래밍',
#    'correct_ratio': 0.4368,
#    'pid': 10272.0,
#    'difficulty': 9}},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/1958',
#    'title': 'LCS 3',
#    'exbank': '백준',
#    'cate1': '고급',
#    'cate2': '3단계',
#    'cate3': '동적 프로그래밍',
#    'correct_ratio': 0.4891,
#    'pid': 1958.0,
#    'difficulty': 9}},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/4243',
#    'title': '보안 업체',
#    'exbank': '백준',
#    'cate1': '고급',
#    'cate2': '3단계',
#    'cate3': '동적 프로그래밍',
#    'correct_ratio': 0.3029,
#    'pid': 4243.0,
#    'difficulty': 9}},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/1344',
#    'title': '축구',
#    'exbank': '백준',
#    'cate1': '고급',
#    'cate2': '3단계',
#    'cate3': '동적 프로그래밍',
#    'correct_ratio': 0.5639,
#    'pid': 1344.0,
#    'difficulty': 9}},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/13250',
#    'title': '주사위 게임',
#    'exbank': '백준',
#    'cate1': '고급',
#    'cate2': '3단계',
#    'cate3': '동적 프로그래밍',
#    'correct_ratio': 0.7061,
#    'pid': 13250.0,
#    'difficulty': 9}},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/2066',
#    'title': '카드놀이',
#    'exbank': '백준',
#    'cate1': '고급',
#    'cate2': '3단계',
#    'cate3': '동적 프로그래밍',
#    'correct_ratio': 0.4383,
#    'pid': 2066.0,
#    'difficulty': 9}},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/3946',
#    'title': '랜덤 걷기',
#    'exbank': '백준',
#    'cate1': '고급',
#    'cate2': '3단계',
#    'cate3': '동적 프로그래밍',
#    'correct_ratio': 0.4615,
#    'pid': 3946.0,
#    'difficulty': 9}},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/1413',
#    'title': '박스 안의 열쇠',
#    'exbank': '백준',
#    'cate1': '고급',
#    'cate2': '3단계',
#    'cate3': '동적 프로그래밍',
#    'correct_ratio': 0.3763,
#    'pid': 1413.0,
#    'difficulty': 9}}]

# %%
i = 1
for hacker in hacker_json:
    hacker['model'] = 'problem.problemex'
    hacker['pk'] = i
    i += 1

# %%
with open('hacker_problem.json','w') in f:
    f.write(json.dumps(hacker_json))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-56-bb98ab33d19f> in <module>
# ----> 1 with open('hacker_problem.json','w') in f:
#       2     f.write(json.dumps(hacker_json))
#
# TypeError: argument of type '_io.BufferedReader' is not iterable

# %%
hacker_json
# Out:
# [{'fields': {'url': 'https://www.hackerrank.com/challenges/py-hello-world',
#    'title': 'Say "Hello, World!" With Python',
#    'exbank': '해커랭크',
#    'cate1': '초급',
#    'cate2': '1단계',
#    'cate3': '변수, 상수, 기초 자료형',
#    'correct_ratio': 0.974628,
#    'pid': None,
#    'difficulty': 1},
#   'model': 'problem.problemex',
#   'pk': 1},
#  {'fields': {'url': 'https://www.hackerrank.com/challenges/python-arithmetic-operators',
#    'title': 'Arithmetic Operators',
#    'exbank': '해커랭크',
#    'cate1': '초급',
#    'cate2': '1단계',
#    'cate3': '연산',
#    'correct_ratio': 0.986746,
#    'pid': None,
#    'difficulty': 1},
#   'model': 'problem.problemex',
#   'pk': 2},
#  {'fields': {'url': 'https://www.hackerrank.com/challenges/python-division',
#    'title': 'Python: Division',
#    'exbank': '해커랭크',
#    'cate1': '초급',
#    'cate2': '1단계',
#    'cate3': '연산',
#    'correct_ratio': 0.987764,
#    'pid': None,
#    'difficulty': 1},
#   'model': 'problem.problemex',
#   'pk': 3},
#  {'fields': {'url': 'https://www.hackerrank.com/challenges/whats-your-name',
#    'title': "What's Your Name?",
#    'exbank': '해커랭크',
#    'cate1': '초급',
#    'cate2': '1단계',
#    'cate3': '입출력 기초',
#    'correct_ratio': 0.979498,
#    'pid': None,
#    'difficulty': 1},
#   'model': 'problem.problemex',
#   'pk': 4},
#  {'fields': {'url': 'https://www.hackerrank.com/challenges/python-mod-divmod',
#    'title': 'Mod Divmod',
#    'exbank': '해커랭크',
#    'cate1': '초급',
#    'cate2': '1단계',
#    'cate3': '연산',
#    'correct_ratio': 0.988857,
#    'pid': None,
#    'difficulty': 1},
#   'model': 'problem.problemex',
#   'pk': 5},
#  {'fields': {'url': 'https://www.hackerrank.com/challenges/python-integers-come-in-all-sizes',
#    'title': 'Integers Come In All Sizes',
#    'exbank': '해커랭크',
#    'cate1': '초급',
#    'cate2': '1단계',
#    'cate3': '변수, 상수, 기초 자료형',
#    'correct_ratio': 0.993011,
#    'pid': None,
#    'difficulty': 1},
#   'model': 'problem.problemex',
#   'pk': 6},
#  {'fields': {'url': 'https://www.hackerrank.com/challenges/input',
#    'title': 'Input()',
#    'exbank': '해커랭크',
#    'cate1': '초급',
#    'cate2': '1단계',
#    'cate3': '입출력 기초',
#    'correct_ratio': 0.957407,
#    'pid': None,
#    'difficulty': 1},
#   'model': 'problem.problemex',
#   'pk': 7},
#  {'fields': {'url': 'https://www.hackerrank.com/challenges/any-or-all',
#    'title': 'Any or All',
#    'exbank': '해커랭크',
#    'cate1': '초급',
#    'cate2': '1단계',
#    'cate3': '연산',
#    'correct_ratio': 0.943856,
#    'pid': None,
#    'difficulty': 1},
#   'model': 'problem.problemex',
#   'pk': 8},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/2557',
#    'title': 'Hello World',
#    'exbank': '백준',
#    'cate1': '초급',
#    'cate2': '1단계',
#    'cate3': '입출력 기초',
#    'correct_ratio': 0.4734,
#    'pid': 2557.0,
#    'difficulty': 1},
#   'model': 'problem.problemex',
#   'pk': 9},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/1000',
#    'title': 'A+B',
#    'exbank': '백준',
#    'cate1': '초급',
#    'cate2': '1단계',
#    'cate3': '연산',
#    'correct_ratio': 0.4525,
#    'pid': 1000.0,
#    'difficulty': 1},
#   'model': 'problem.problemex',
#   'pk': 10},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/1001',
#    'title': 'A-B',
#    'exbank': '백준',
#    'cate1': '초급',
#    'cate2': '1단계',
#    'cate3': '연산',
#    'correct_ratio': 0.7207,
#    'pid': 1001.0,
#    'difficulty': 1},
#   'model': 'problem.problemex',
#   'pk': 11},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/7287',
#    'title': '등록',
#    'exbank': '백준',
#    'cate1': '초급',
#    'cate2': '1단계',
#    'cate3': '입출력 기초',
#    'correct_ratio': 0.4784,
#    'pid': 7287.0,
#    'difficulty': 1},
#   'model': 'problem.problemex',
#   'pk': 12},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/10172',
#    'title': '개',
#    'exbank': '백준',
#    'cate1': '초급',
#    'cate2': '1단계',
#    'cate3': '입출력 기초',
#    'correct_ratio': 0.3707,
#    'pid': 10172.0,
#    'difficulty': 1},
#   'model': 'problem.problemex',
#   'pk': 13},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/10718',
#    'title': 'We love kriii',
#    'exbank': '백준',
#    'cate1': '초급',
#    'cate2': '1단계',
#    'cate3': '입출력 기초',
#    'correct_ratio': 0.7831,
#    'pid': 10718.0,
#    'difficulty': 1},
#   'model': 'problem.problemex',
#   'pk': 14},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/11718',
#    'title': '그대로 출력하기',
#    'exbank': '백준',
#    'cate1': '초급',
#    'cate2': '1단계',
#    'cate3': '입출력 기초',
#    'correct_ratio': 0.2522,
#    'pid': 11718.0,
#    'difficulty': 1},
#   'model': 'problem.problemex',
#   'pk': 15},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/11719',
#    'title': '그대로 출력하기 2',
#    'exbank': '백준',
#    'cate1': '초급',
#    'cate2': '1단계',
#    'cate3': '입출력 기초',
#    'correct_ratio': 0.569,
#    'pid': 11719.0,
#    'difficulty': 1},
#   'model': 'problem.problemex',
#   'pk': 16},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/10998',
#    'title': 'A×B',
#    'exbank': '백준',
#    'cate1': '초급',
#    'cate2': '1단계',
#    'cate3': '연산',
#    'correct_ratio': 0.768,
#    'pid': 10998.0,
#    'difficulty': 1},
#   'model': 'problem.problemex',
#   'pk': 17},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/1008',
#    'title': 'A/B',
#    'exbank': '백준',
#    'cate1': '초급',
#    'cate2': '1단계',
#    'cate3': '연산',
#    'correct_ratio': 0.3401,
#    'pid': 1008.0,
#    'difficulty': 1},
#   'model': 'problem.problemex',
#   'pk': 18},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/10869',
#    'title': '사칙연산',
#    'exbank': '백준',
#    'cate1': '초급',
#    'cate2': '1단계',
#    'cate3': '연산',
#    'correct_ratio': 0.5834,
#    'pid': 10869.0,
#    'difficulty': 1},
#   'model': 'problem.problemex',
#   'pk': 19},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/10430',
#    'title': '나머지',
#    'exbank': '백준',
#    'cate1': '초급',
#    'cate2': '1단계',
#    'cate3': '연산',
#    'correct_ratio': 0.6166,
#    'pid': 10430.0,
#    'difficulty': 1},
#   'model': 'problem.problemex',
#   'pk': 20},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/2558',
#    'title': 'A+B 2',
#    'exbank': '백준',
#    'cate1': '초급',
#    'cate2': '1단계',
#    'cate3': '연산',
#    'correct_ratio': 0.7546,
#    'pid': 2558.0,
#    'difficulty': 1},
#   'model': 'problem.problemex',
#   'pk': 21},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/3053',
#    'title': '택시 기하학',
#    'exbank': '백준',
#    'cate1': '초급',
#    'cate2': '1단계',
#    'cate3': '연산',
#    'correct_ratio': 0.4175,
#    'pid': 3053.0,
#    'difficulty': 1},
#   'model': 'problem.problemex',
#   'pk': 22},
#  {'fields': {'url': 'https://www.hackerrank.com/challenges/py-if-else',
#    'title': 'Python If-Else',
#    'exbank': '해커랭크',
#    'cate1': '초급',
#    'cate2': '2단계',
#    'cate3': '흐름제어',
#    'correct_ratio': 0.912253,
#    'pid': None,
#    'difficulty': 2},
#   'model': 'problem.problemex',
#   'pk': 23},
#  {'fields': {'url': 'https://www.hackerrank.com/challenges/python-loops',
#    'title': 'Loops',
#    'exbank': '해커랭크',
#    'cate1': '초급',
#    'cate2': '2단계',
#    'cate3': '흐름제어',
#    'correct_ratio': 0.98422,
#    'pid': None,
#    'difficulty': 2},
#   'model': 'problem.problemex',
#   'pk': 24},
#  {'fields': {'url': 'https://www.hackerrank.com/challenges/write-a-function',
#    'title': 'Write a function',
#    'exbank': '해커랭크',
#    'cate1': '초급',
#    'cate2': '2단계',
#    'cate3': '흐름제어',
#    'correct_ratio': 0.902642,
#    'pid': None,
#    'difficulty': 2},
#   'model': 'problem.problemex',
#   'pk': 25},
#  {'fields': {'url': 'https://www.hackerrank.com/challenges/python-print',
#    'title': 'Print Function',
#    'exbank': '해커랭크',
#    'cate1': '초급',
#    'cate2': '2단계',
#    'cate3': '흐름제어',
#    'correct_ratio': 0.958743,
#    'pid': None,
#    'difficulty': 2},
#   'model': 'problem.problemex',
#   'pk': 26},
#  {'fields': {'url': 'https://www.hackerrank.com/challenges/text-alignment',
#    'title': 'Text Alignment',
#    'exbank': '해커랭크',
#    'cate1': '초급',
#    'cate2': '2단계',
#    'cate3': '흐름제어',
#    'correct_ratio': 0.981402,
#    'pid': None,
#    'difficulty': 2},
#   'model': 'problem.problemex',
#   'pk': 27},
#  {'fields': {'url': 'https://www.hackerrank.com/challenges/alphabet-rangoli',
#    'title': 'Alphabet Rangoli',
#    'exbank': '해커랭크',
#    'cate1': '초급',
#    'cate2': '2단계',
#    'cate3': '흐름제어',
#    'correct_ratio': 0.973757,
#    'pid': None,
#    'difficulty': 2},
#   'model': 'problem.problemex',
#   'pk': 28},
#  {'fields': {'url': 'https://www.hackerrank.com/challenges/the-minion-game',
#    'title': 'The Minion Game',
#    'exbank': '해커랭크',
#    'cate1': '초급',
#    'cate2': '2단계',
#    'cate3': '흐름제어',
#    'correct_ratio': 0.854372,
#    'pid': None,
#    'difficulty': 2},
#   'model': 'problem.problemex',
#   'pk': 29},
#  {'fields': {'url': 'https://www.hackerrank.com/challenges/triangle-quest-2',
#    'title': 'Triangle Quest 2',
#    'exbank': '해커랭크',
#    'cate1': '초급',
#    'cate2': '2단계',
#    'cate3': '흐름제어',
#    'correct_ratio': 0.951749,
#    'pid': None,
#    'difficulty': 2},
#   'model': 'problem.problemex',
#   'pk': 30},
#  {'fields': {'url': 'https://www.hackerrank.com/challenges/python-quest-1',
#    'title': 'Triangle Quest',
#    'exbank': '해커랭크',
#    'cate1': '초급',
#    'cate2': '2단계',
#    'cate3': '흐름제어',
#    'correct_ratio': 0.915984,
#    'pid': None,
#    'difficulty': 2},
#   'model': 'problem.problemex',
#   'pk': 31},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/2839',
#    'title': '설탕 배달',
#    'exbank': '백준',
#    'cate1': '초급',
#    'cate2': '2단계',
#    'cate3': '흐름제어',
#    'correct_ratio': 0.2885,
#    'pid': 2839.0,
#    'difficulty': 2},
#   'model': 'problem.problemex',
#   'pk': 32},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/2741',
#    'title': 'N 찍기',
#    'exbank': '백준',
#    'cate1': '초급',
#    'cate2': '2단계',
#    'cate3': '흐름제어',
#    'correct_ratio': 0.4498,
#    'pid': 2741.0,
#    'difficulty': 2},
#   'model': 'problem.problemex',
#   'pk': 33},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/2742',
#    'title': '기찍 N',
#    'exbank': '백준',
#    'cate1': '초급',
#    'cate2': '2단계',
#    'cate3': '흐름제어',
#    'correct_ratio': 0.648,
#    'pid': 2742.0,
#    'difficulty': 2},
#   'model': 'problem.problemex',
#   'pk': 34},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/2739',
#    'title': '구구단',
#    'exbank': '백준',
#    'cate1': '초급',
#    'cate2': '2단계',
#    'cate3': '흐름제어',
#    'correct_ratio': 0.5597,
#    'pid': 2739.0,
#    'difficulty': 2},
#   'model': 'problem.problemex',
#   'pk': 35},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/2438',
#    'title': '별 찍기 1',
#    'exbank': '백준',
#    'cate1': '초급',
#    'cate2': '2단계',
#    'cate3': '흐름제어',
#    'correct_ratio': 0.6157,
#    'pid': 2438.0,
#    'difficulty': 2},
#   'model': 'problem.problemex',
#   'pk': 36},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/2439',
#    'title': '별 찍기 2',
#    'exbank': '백준',
#    'cate1': '초급',
#    'cate2': '2단계',
#    'cate3': '흐름제어',
#    'correct_ratio': 0.5935,
#    'pid': 2439.0,
#    'difficulty': 2},
#   'model': 'problem.problemex',
#   'pk': 37},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/2440',
#    'title': '별 찍기 3',
#    'exbank': '백준',
#    'cate1': '초급',
#    'cate2': '2단계',
#    'cate3': '흐름제어',
#    'correct_ratio': 0.6661,
#    'pid': 2440.0,
#    'difficulty': 2},
#   'model': 'problem.problemex',
#   'pk': 38},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/2441',
#    'title': '별 찍기 4',
#    'exbank': '백준',
#    'cate1': '초급',
#    'cate2': '2단계',
#    'cate3': '흐름제어',
#    'correct_ratio': 0.7335,
#    'pid': 2441.0,
#    'difficulty': 2},
#   'model': 'problem.problemex',
#   'pk': 39},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/1924',
#    'title': '2007년',
#    'exbank': '백준',
#    'cate1': '초급',
#    'cate2': '2단계',
#    'cate3': '흐름제어',
#    'correct_ratio': 0.4414,
#    'pid': 1924.0,
#    'difficulty': 2},
#   'model': 'problem.problemex',
#   'pk': 40},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/8393',
#    'title': '합',
#    'exbank': '백준',
#    'cate1': '초급',
#    'cate2': '2단계',
#    'cate3': '흐름제어',
#    'correct_ratio': 0.7356,
#    'pid': 8393.0,
#    'difficulty': 2},
#   'model': 'problem.problemex',
#   'pk': 41},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/11720',
#    'title': '숫자의 합',
#    'exbank': '백준',
#    'cate1': '초급',
#    'cate2': '2단계',
#    'cate3': '흐름제어',
#    'correct_ratio': 0.466,
#    'pid': 11720.0,
#    'difficulty': 2},
#   'model': 'problem.problemex',
#   'pk': 42},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/11721',
#    'title': '열 개씩 끊어 출력하기',
#    'exbank': '백준',
#    'cate1': '초급',
#    'cate2': '2단계',
#    'cate3': '흐름제어',
#    'correct_ratio': 0.5122,
#    'pid': 11721.0,
#    'difficulty': 2},
#   'model': 'problem.problemex',
#   'pk': 43},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/15552',
#    'title': '빠른 A+B',
#    'exbank': '백준',
#    'cate1': '초급',
#    'cate2': '2단계',
#    'cate3': '흐름제어',
#    'correct_ratio': 0.5058,
#    'pid': 15552.0,
#    'difficulty': 2},
#   'model': 'problem.problemex',
#   'pk': 44},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/9498',
#    'title': '시험 성적',
#    'exbank': '백준',
#    'cate1': '초급',
#    'cate2': '2단계',
#    'cate3': '흐름제어',
#    'correct_ratio': 0.6198,
#    'pid': 9498.0,
#    'difficulty': 2},
#   'model': 'problem.problemex',
#   'pk': 45},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/10817',
#    'title': '세 수',
#    'exbank': '백준',
#    'cate1': '초급',
#    'cate2': '2단계',
#    'cate3': '흐름제어',
#    'correct_ratio': 0.4714,
#    'pid': 10817.0,
#    'difficulty': 2},
#   'model': 'problem.problemex',
#   'pk': 46},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/10871',
#    'title': 'X보다 작은 수',
#    'exbank': '백준',
#    'cate1': '초급',
#    'cate2': '2단계',
#    'cate3': '흐름제어',
#    'correct_ratio': 0.5817,
#    'pid': 10871.0,
#    'difficulty': 2},
#   'model': 'problem.problemex',
#   'pk': 47},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/1546',
#    'title': '평균',
#    'exbank': '백준',
#    'cate1': '초급',
#    'cate2': '2단계',
#    'cate3': '흐름제어',
#    'correct_ratio': 0.4705,
#    'pid': 1546.0,
#    'difficulty': 2},
#   'model': 'problem.problemex',
#   'pk': 48},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/4344',
#    'title': '평균은 넘겠지',
#    'exbank': '백준',
#    'cate1': '초급',
#    'cate2': '2단계',
#    'cate3': '흐름제어',
#    'correct_ratio': 0.3844,
#    'pid': 4344.0,
#    'difficulty': 2},
#   'model': 'problem.problemex',
#   'pk': 49},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/1110',
#    'title': '더하기 사이클',
#    'exbank': '백준',
#    'cate1': '초급',
#    'cate2': '2단계',
#    'cate3': '흐름제어',
#    'correct_ratio': 0.502,
#    'pid': 1110.0,
#    'difficulty': 2},
#   'model': 'problem.problemex',
#   'pk': 50},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/4673',
#    'title': '셀프 넘버',
#    'exbank': '백준',
#    'cate1': '초급',
#    'cate2': '2단계',
#    'cate3': '흐름제어',
#    'correct_ratio': 0.5312,
#    'pid': 4673.0,
#    'difficulty': 2},
#   'model': 'problem.problemex',
#   'pk': 51},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/2448',
#    'title': '별 찍기 11',
#    'exbank': '백준',
#    'cate1': '초급',
#    'cate2': '2단계',
#    'cate3': '흐름제어',
#    'correct_ratio': 0.3631,
#    'pid': 2448.0,
#    'difficulty': 2},
#   'model': 'problem.problemex',
#   'pk': 52},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/2747',
#    'title': '피보나치 수',
#    'exbank': '백준',
#    'cate1': '초급',
#    'cate2': '2단계',
#    'cate3': '흐름제어',
#    'correct_ratio': 0.4687,
#    'pid': 2747.0,
#    'difficulty': 2},
#   'model': 'problem.problemex',
#   'pk': 53},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/1676',
#    'title': '팩토리얼 0의 개수',
#    'exbank': '백준',
#    'cate1': '초급',
#    'cate2': '2단계',
#    'cate3': '흐름제어',
#    'correct_ratio': 0.4607,
#    'pid': 1676.0,
#    'difficulty': 2},
#   'model': 'problem.problemex',
#   'pk': 54},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/6591',
#    'title': '이항 쇼다운',
#    'exbank': '백준',
#    'cate1': '초급',
#    'cate2': '2단계',
#    'cate3': '흐름제어',
#    'correct_ratio': 0.2399,
#    'pid': 6591.0,
#    'difficulty': 2},
#   'model': 'problem.problemex',
#   'pk': 55},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/2490',
#    'title': '윷놀이',
#    'exbank': '백준',
#    'cate1': '초급',
#    'cate2': '2단계',
#    'cate3': '흐름제어',
#    'correct_ratio': 0.5909,
#    'pid': 2490.0,
#    'difficulty': 2},
#   'model': 'problem.problemex',
#   'pk': 56},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/1022',
#    'title': '소용돌이 예쁘게 출력하기',
#    'exbank': '백준',
#    'cate1': '초급',
#    'cate2': '2단계',
#    'cate3': '흐름제어',
#    'correct_ratio': 0.3136,
#    'pid': 1022.0,
#    'difficulty': 2},
#   'model': 'problem.problemex',
#   'pk': 57},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/2455',
#    'title': '지능형 기차',
#    'exbank': '백준',
#    'cate1': '초급',
#    'cate2': '2단계',
#    'cate3': '흐름제어',
#    'correct_ratio': 0.8004,
#    'pid': 2455.0,
#    'difficulty': 2},
#   'model': 'problem.problemex',
#   'pk': 58},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/1094',
#    'title': '막대기',
#    'exbank': '백준',
#    'cate1': '초급',
#    'cate2': '2단계',
#    'cate3': '흐름제어',
#    'correct_ratio': 0.7328,
#    'pid': 1094.0,
#    'difficulty': 2},
#   'model': 'problem.problemex',
#   'pk': 59},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/1057',
#    'title': '토너먼트',
#    'exbank': '백준',
#    'cate1': '초급',
#    'cate2': '2단계',
#    'cate3': '흐름제어',
#    'correct_ratio': 0.5499,
#    'pid': 1057.0,
#    'difficulty': 2},
#   'model': 'problem.problemex',
#   'pk': 60},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/1024',
#    'title': '수열의 합',
#    'exbank': '백준',
#    'cate1': '초급',
#    'cate2': '2단계',
#    'cate3': '흐름제어',
#    'correct_ratio': 0.2582,
#    'pid': 1024.0,
#    'difficulty': 2},
#   'model': 'problem.problemex',
#   'pk': 61},
#  {'fields': {'url': 'https://www.hackerrank.com/challenges/list-comprehensions',
#    'title': 'List Comprehensions',
#    'exbank': '해커랭크',
#    'cate1': '중급',
#    'cate2': '2단계',
#    'cate3': '고급 자료형',
#    'correct_ratio': 0.984657,
#    'pid': None,
#    'difficulty': 5},
#   'model': 'problem.problemex',
#   'pk': 62},
#  {'fields': {'url': 'https://www.hackerrank.com/challenges/find-second-maximum-number-in-a-list',
#    'title': 'Find the Runner-Up Score!',
#    'exbank': '해커랭크',
#    'cate1': '중급',
#    'cate2': '2단계',
#    'cate3': '자료구조',
#    'correct_ratio': 0.939112,
#    'pid': None,
#    'difficulty': 5},
#   'model': 'problem.problemex',
#   'pk': 63},
#  {'fields': {'url': 'https://www.hackerrank.com/challenges/itertools-product',
#    'title': 'itertools.product()',
#    'exbank': '해커랭크',
#    'cate1': '중급',
#    'cate2': '2단계',
#    'cate3': '모듈과 패키지',
#    'correct_ratio': 0.980374,
#    'pid': None,
#    'difficulty': 5},
#   'model': 'problem.problemex',
#   'pk': 64},
#  {'fields': {'url': 'https://www.hackerrank.com/challenges/collections-counter',
#    'title': 'collections.Counter()',
#    'exbank': '해커랭크',
#    'cate1': '중급',
#    'cate2': '2단계',
#    'cate3': '모듈과 패키지',
#    'correct_ratio': 0.984318,
#    'pid': None,
#    'difficulty': 5},
#   'model': 'problem.problemex',
#   'pk': 65},
#  {'fields': {'url': 'https://www.hackerrank.com/challenges/itertools-permutations',
#    'title': 'itertools.permutations()',
#    'exbank': '해커랭크',
#    'cate1': '중급',
#    'cate2': '2단계',
#    'cate3': '모듈과 패키지',
#    'correct_ratio': 0.980007,
#    'pid': None,
#    'difficulty': 5},
#   'model': 'problem.problemex',
#   'pk': 66},
#  {'fields': {'url': 'https://www.hackerrank.com/challenges/polar-coordinates',
#    'title': 'Polar Coordinates',
#    'exbank': '해커랭크',
#    'cate1': '중급',
#    'cate2': '2단계',
#    'cate3': '모듈과 패키지',
#    'correct_ratio': 0.944711,
#    'pid': None,
#    'difficulty': 5},
#   'model': 'problem.problemex',
#   'pk': 67},
#  {'fields': {'url': 'https://www.hackerrank.com/challenges/py-introduction-to-sets',
#    'title': 'Introduction to Sets',
#    'exbank': '해커랭크',
#    'cate1': '중급',
#    'cate2': '2단계',
#    'cate3': '고급 자료형',
#    'correct_ratio': 0.982999,
#    'pid': None,
#    'difficulty': 5},
#   'model': 'problem.problemex',
#   'pk': 68},
#  {'fields': {'url': 'https://www.hackerrank.com/challenges/calendar-module',
#    'title': 'Calendar Module',
#    'exbank': '해커랭크',
#    'cate1': '중급',
#    'cate2': '2단계',
#    'cate3': '모듈과 패키지',
#    'correct_ratio': 0.972119,
#    'pid': None,
#    'difficulty': 5},
#   'model': 'problem.problemex',
#   'pk': 69},
#  {'fields': {'url': 'https://www.hackerrank.com/challenges/py-collections-namedtuple',
#    'title': 'Collections.namedtuple()',
#    'exbank': '해커랭크',
#    'cate1': '중급',
#    'cate2': '2단계',
#    'cate3': '모듈과 패키지',
#    'correct_ratio': 0.978824,
#    'pid': None,
#    'difficulty': 5},
#   'model': 'problem.problemex',
#   'pk': 70},
#  {'fields': {'url': 'https://www.hackerrank.com/challenges/python-time-delta',
#    'title': 'Time Delta',
#    'exbank': '해커랭크',
#    'cate1': '중급',
#    'cate2': '2단계',
#    'cate3': '모듈과 패키지',
#    'correct_ratio': 0.916956,
#    'pid': None,
#    'difficulty': 5},
#   'model': 'problem.problemex',
#   'pk': 71},
#  {'fields': {'url': 'https://www.hackerrank.com/challenges/find-angle',
#    'title': 'Find Angle MBC',
#    'exbank': '해커랭크',
#    'cate1': '중급',
#    'cate2': '2단계',
#    'cate3': '모듈과 패키지',
#    'correct_ratio': 0.871596,
#    'pid': None,
#    'difficulty': 5},
#   'model': 'problem.problemex',
#   'pk': 72},
#  {'fields': {'url': 'https://www.hackerrank.com/challenges/no-idea',
#    'title': 'No Idea!',
#    'exbank': '해커랭크',
#    'cate1': '중급',
#    'cate2': '2단계',
#    'cate3': '모듈과 패키지',
#    'correct_ratio': 0.861785,
#    'pid': None,
#    'difficulty': 5},
#   'model': 'problem.problemex',
#   'pk': 73},
#  {'fields': {'url': 'https://www.hackerrank.com/challenges/py-collections-ordereddict',
#    'title': 'Collections.OrderedDict()',
#    'exbank': '해커랭크',
#    'cate1': '중급',
#    'cate2': '2단계',
#    'cate3': '모듈과 패키지',
#    'correct_ratio': 0.987974,
#    'pid': None,
#    'difficulty': 5},
#   'model': 'problem.problemex',
#   'pk': 74},
#  {'fields': {'url': 'https://www.hackerrank.com/challenges/symmetric-difference',
#    'title': 'Symmetric Difference',
#    'exbank': '해커랭크',
#    'cate1': '중급',
#    'cate2': '2단계',
#    'cate3': '모듈과 패키지',
#    'correct_ratio': 0.981304,
#    'pid': None,
#    'difficulty': 5},
#   'model': 'problem.problemex',
#   'pk': 75},
#  {'fields': {'url': 'https://www.hackerrank.com/challenges/itertools-combinations',
#    'title': 'itertools.combinations()',
#    'exbank': '해커랭크',
#    'cate1': '중급',
#    'cate2': '2단계',
#    'cate3': '모듈과 패키지',
#    'correct_ratio': 0.976345,
#    'pid': None,
#    'difficulty': 5},
#   'model': 'problem.problemex',
#   'pk': 76},
#  {'fields': {'url': 'https://www.hackerrank.com/challenges/itertools-combinations-with-replacement',
#    'title': 'itertools.combinations_with_replacement()',
#    'exbank': '해커랭크',
#    'cate1': '중급',
#    'cate2': '2단계',
#    'cate3': '모듈과 패키지',
#    'correct_ratio': 0.989537,
#    'pid': None,
#    'difficulty': 5},
#   'model': 'problem.problemex',
#   'pk': 77},
#  {'fields': {'url': 'https://www.hackerrank.com/challenges/py-collections-deque',
#    'title': 'Collections.deque()',
#    'exbank': '해커랭크',
#    'cate1': '중급',
#    'cate2': '2단계',
#    'cate3': '모듈과 패키지',
#    'correct_ratio': 0.984722,
#    'pid': None,
#    'difficulty': 5},
#   'model': 'problem.problemex',
#   'pk': 78},
#  {'fields': {'url': 'https://www.hackerrank.com/challenges/compress-the-string',
#    'title': 'Compress the String!',
#    'exbank': '해커랭크',
#    'cate1': '중급',
#    'cate2': '2단계',
#    'cate3': '모듈과 패키지',
#    'correct_ratio': 0.977239,
#    'pid': None,
#    'difficulty': 5},
#   'model': 'problem.problemex',
#   'pk': 79},
#  {'fields': {'url': 'https://www.hackerrank.com/challenges/piling-up',
#    'title': 'Piling Up!',
#    'exbank': '해커랭크',
#    'cate1': '중급',
#    'cate2': '2단계',
#    'cate3': '자료구조',
#    'correct_ratio': 0.897481,
#    'pid': None,
#    'difficulty': 5},
#   'model': 'problem.problemex',
#   'pk': 80},
#  {'fields': {'url': 'https://www.hackerrank.com/challenges/iterables-and-iterators',
#    'title': 'Iterables and Iterators',
#    'exbank': '해커랭크',
#    'cate1': '중급',
#    'cate2': '2단계',
#    'cate3': '모듈과 패키지',
#    'correct_ratio': 0.966448,
#    'pid': None,
#    'difficulty': 5},
#   'model': 'problem.problemex',
#   'pk': 81},
#  {'fields': {'url': 'https://www.hackerrank.com/challenges/maximize-it',
#    'title': 'Maximize It!',
#    'exbank': '해커랭크',
#    'cate1': '중급',
#    'cate2': '2단계',
#    'cate3': '모듈과 패키지',
#    'correct_ratio': 0.81415,
#    'pid': None,
#    'difficulty': 5},
#   'model': 'problem.problemex',
#   'pk': 82},
#  {'fields': {'url': 'https://www.hackerrank.com/challenges/py-check-subset',
#    'title': 'Check Subset',
#    'exbank': '해커랭크',
#    'cate1': '중급',
#    'cate2': '2단계',
#    'cate3': '고급 자료형',
#    'correct_ratio': 0.986416,
#    'pid': None,
#    'difficulty': 5},
#   'model': 'problem.problemex',
#   'pk': 83},
#  {'fields': {'url': 'https://www.hackerrank.com/challenges/py-check-strict-superset',
#    'title': 'Check Strict Superset',
#    'exbank': '해커랭크',
#    'cate1': '중급',
#    'cate2': '2단계',
#    'cate3': '고급 자료형',
#    'correct_ratio': 0.95533,
#    'pid': None,
#    'difficulty': 5},
#   'model': 'problem.problemex',
#   'pk': 84},
#  {'fields': {'url': 'https://www.hackerrank.com/challenges/map-and-lambda-expression',
#    'title': 'Map and Lambda Function',
#    'exbank': '해커랭크',
#    'cate1': '중급',
#    'cate2': '2단계',
#    'cate3': '고급 자료형',
#    'correct_ratio': 0.940121,
#    'pid': None,
#    'difficulty': 5},
#   'model': 'problem.problemex',
#   'pk': 85},
#  {'fields': {'url': 'https://www.hackerrank.com/challenges/reduce-function',
#    'title': 'Reduce Function',
#    'exbank': '해커랭크',
#    'cate1': '중급',
#    'cate2': '2단계',
#    'cate3': '고급 자료형',
#    'correct_ratio': 0.985904,
#    'pid': None,
#    'difficulty': 5},
#   'model': 'problem.problemex',
#   'pk': 86},
#  {'fields': {'url': 'https://www.hackerrank.com/challenges/decorators-2-name-directory',
#    'title': 'Decorators 2 - Name Directory',
#    'exbank': '해커랭크',
#    'cate1': '중급',
#    'cate2': '2단계',
#    'cate3': '모듈과 패키지',
#    'correct_ratio': 0.907428,
#    'pid': None,
#    'difficulty': 5},
#   'model': 'problem.problemex',
#   'pk': 87},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/10828',
#    'title': '스택',
#    'exbank': '백준',
#    'cate1': '중급',
#    'cate2': '2단계',
#    'cate3': '자료구조',
#    'correct_ratio': 0.4114,
#    'pid': 10828.0,
#    'difficulty': 5},
#   'model': 'problem.problemex',
#   'pk': 88},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/1874',
#    'title': '스택 수열',
#    'exbank': '백준',
#    'cate1': '중급',
#    'cate2': '2단계',
#    'cate3': '자료구조',
#    'correct_ratio': 0.2892,
#    'pid': 1874.0,
#    'difficulty': 5},
#   'model': 'problem.problemex',
#   'pk': 89},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/9012',
#    'title': '괄호',
#    'exbank': '백준',
#    'cate1': '중급',
#    'cate2': '2단계',
#    'cate3': '자료구조',
#    'correct_ratio': 0.3901,
#    'pid': 9012.0,
#    'difficulty': 5},
#   'model': 'problem.problemex',
#   'pk': 90},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/2504',
#    'title': '괄호의 값',
#    'exbank': '백준',
#    'cate1': '중급',
#    'cate2': '2단계',
#    'cate3': '자료구조',
#    'correct_ratio': 0.2839,
#    'pid': 2504.0,
#    'difficulty': 5},
#   'model': 'problem.problemex',
#   'pk': 91},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/10845',
#    'title': '큐',
#    'exbank': '백준',
#    'cate1': '중급',
#    'cate2': '2단계',
#    'cate3': '자료구조',
#    'correct_ratio': 0.5073,
#    'pid': 10845.0,
#    'difficulty': 5},
#   'model': 'problem.problemex',
#   'pk': 92},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/1260',
#    'title': 'DFS와 BFS',
#    'exbank': '백준',
#    'cate1': '중급',
#    'cate2': '2단계',
#    'cate3': '자료구조',
#    'correct_ratio': 0.2942,
#    'pid': 1260.0,
#    'difficulty': 5},
#   'model': 'problem.problemex',
#   'pk': 93},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/1966',
#    'title': '프린터 큐',
#    'exbank': '백준',
#    'cate1': '중급',
#    'cate2': '2단계',
#    'cate3': '자료구조',
#    'correct_ratio': 0.5267,
#    'pid': 1966.0,
#    'difficulty': 5},
#   'model': 'problem.problemex',
#   'pk': 94},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/11866',
#    'title': '조세퍼스 문제 0',
#    'exbank': '백준',
#    'cate1': '중급',
#    'cate2': '2단계',
#    'cate3': '자료구조',
#    'correct_ratio': 0.5901,
#    'pid': 11866.0,
#    'difficulty': 5},
#   'model': 'problem.problemex',
#   'pk': 95},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/1158',
#    'title': '조세퍼스 문제',
#    'exbank': '백준',
#    'cate1': '중급',
#    'cate2': '2단계',
#    'cate3': '자료구조',
#    'correct_ratio': 0.5091,
#    'pid': 1158.0,
#    'difficulty': 5},
#   'model': 'problem.problemex',
#   'pk': 96},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/10866',
#    'title': '덱',
#    'exbank': '백준',
#    'cate1': '중급',
#    'cate2': '2단계',
#    'cate3': '자료구조',
#    'correct_ratio': 0.5398,
#    'pid': 10866.0,
#    'difficulty': 5},
#   'model': 'problem.problemex',
#   'pk': 97},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/1021',
#    'title': '회전하는 큐',
#    'exbank': '백준',
#    'cate1': '중급',
#    'cate2': '2단계',
#    'cate3': '자료구조',
#    'correct_ratio': 0.3947,
#    'pid': 1021.0,
#    'difficulty': 5},
#   'model': 'problem.problemex',
#   'pk': 98},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/5430',
#    'title': 'AC',
#    'exbank': '백준',
#    'cate1': '중급',
#    'cate2': '2단계',
#    'cate3': '자료구조',
#    'correct_ratio': 0.1917,
#    'pid': 5430.0,
#    'difficulty': 5},
#   'model': 'problem.problemex',
#   'pk': 99},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/1991',
#    'title': '트리 순회',
#    'exbank': '백준',
#    'cate1': '중급',
#    'cate2': '2단계',
#    'cate3': '자료구조',
#    'correct_ratio': 0.6195,
#    'pid': 1991.0,
#    'difficulty': 5},
#   'model': 'problem.problemex',
#   'pk': 100},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/2957',
#    'title': '이진 탐색 트리',
#    'exbank': '백준',
#    'cate1': '중급',
#    'cate2': '2단계',
#    'cate3': '자료구조',
#    'correct_ratio': 0.2298,
#    'pid': 2957.0,
#    'difficulty': 5},
#   'model': 'problem.problemex',
#   'pk': 101},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/5639',
#    'title': '이진 검색 트리',
#    'exbank': '백준',
#    'cate1': '중급',
#    'cate2': '2단계',
#    'cate3': '자료구조',
#    'correct_ratio': 0.432,
#    'pid': 5639.0,
#    'difficulty': 5},
#   'model': 'problem.problemex',
#   'pk': 102},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/3038',
#    'title': '완전 이진 트리',
#    'exbank': '백준',
#    'cate1': '중급',
#    'cate2': '2단계',
#    'cate3': '자료구조',
#    'correct_ratio': 0.596,
#    'pid': 3038.0,
#    'difficulty': 5},
#   'model': 'problem.problemex',
#   'pk': 103},
#  {'fields': {'url': 'https://www.hackerrank.com/challenges/nested-list',
#    'title': 'Nested Lists',
#    'exbank': '해커랭크',
#    'cate1': '초급',
#    'cate2': '3단계',
#    'cate3': 'list',
#    'correct_ratio': 0.898807,
#    'pid': None,
#    'difficulty': 3},
#   'model': 'problem.problemex',
#   'pk': 104},
#  {'fields': {'url': 'https://www.hackerrank.com/challenges/python-lists',
#    'title': 'Lists',
#    'exbank': '해커랭크',
#    'cate1': '초급',
#    'cate2': '3단계',
#    'cate3': 'list',
#    'correct_ratio': 0.895305,
#    'pid': None,
#    'difficulty': 3},
#   'model': 'problem.problemex',
#   'pk': 105},
#  {'fields': {'url': 'https://www.hackerrank.com/challenges/python-tuples',
#    'title': 'Tuples',
#    'exbank': '해커랭크',
#    'cate1': '초급',
#    'cate2': '3단계',
#    'cate3': 'tuple',
#    'correct_ratio': 0.981736,
#    'pid': None,
#    'difficulty': 3},
#   'model': 'problem.problemex',
#   'pk': 106},
#  {'fields': {'url': 'https://www.hackerrank.com/challenges/swap-case',
#    'title': 'sWAP cASE',
#    'exbank': '해커랭크',
#    'cate1': '초급',
#    'cate2': '3단계',
#    'cate3': '문자열 이용',
#    'correct_ratio': 0.985278,
#    'pid': None,
#    'difficulty': 3},
#   'model': 'problem.problemex',
#   'pk': 107},
#  {'fields': {'url': 'https://www.hackerrank.com/challenges/python-string-split-and-join',
#    'title': 'String Split and Join',
#    'exbank': '해커랭크',
#    'cate1': '초급',
#    'cate2': '3단계',
#    'cate3': '문자열 이용',
#    'correct_ratio': 0.987638,
#    'pid': None,
#    'difficulty': 3},
#   'model': 'problem.problemex',
#   'pk': 108},
#  {'fields': {'url': 'https://www.hackerrank.com/challenges/python-mutations',
#    'title': 'Mutations',
#    'exbank': '해커랭크',
#    'cate1': '초급',
#    'cate2': '3단계',
#    'cate3': '문자열 이용',
#    'correct_ratio': 0.98181,
#    'pid': None,
#    'difficulty': 3},
#   'model': 'problem.problemex',
#   'pk': 109},
#  {'fields': {'url': 'https://www.hackerrank.com/challenges/find-a-string',
#    'title': 'Find a string',
#    'exbank': '해커랭크',
#    'cate1': '초급',
#    'cate2': '3단계',
#    'cate3': '문자열 이용',
#    'correct_ratio': 0.936213,
#    'pid': None,
#    'difficulty': 3},
#   'model': 'problem.problemex',
#   'pk': 110},
#  {'fields': {'url': 'https://www.hackerrank.com/challenges/text-wrap',
#    'title': 'Text Wrap',
#    'exbank': '해커랭크',
#    'cate1': '초급',
#    'cate2': '3단계',
#    'cate3': '문자열 이용',
#    'correct_ratio': 0.988032,
#    'pid': None,
#    'difficulty': 3},
#   'model': 'problem.problemex',
#   'pk': 111},
#  {'fields': {'url': 'https://www.hackerrank.com/challenges/capitalize',
#    'title': 'Capitalize!',
#    'exbank': '해커랭크',
#    'cate1': '초급',
#    'cate2': '3단계',
#    'cate3': '문자열 이용',
#    'correct_ratio': 0.821237,
#    'pid': None,
#    'difficulty': 3},
#   'model': 'problem.problemex',
#   'pk': 112},
#  {'fields': {'url': 'https://www.hackerrank.com/challenges/merge-the-tools',
#    'title': 'Merge the Tools!',
#    'exbank': '해커랭크',
#    'cate1': '초급',
#    'cate2': '3단계',
#    'cate3': '문자열 이용',
#    'correct_ratio': 0.926066,
#    'pid': None,
#    'difficulty': 3},
#   'model': 'problem.problemex',
#   'pk': 113},
#  {'fields': {'url': 'https://www.hackerrank.com/challenges/defaultdict-tutorial',
#    'title': 'DefaultDict Tutorial',
#    'exbank': '해커랭크',
#    'cate1': '초급',
#    'cate2': '3단계',
#    'cate3': 'list',
#    'correct_ratio': 0.929442,
#    'pid': None,
#    'difficulty': 3},
#   'model': 'problem.problemex',
#   'pk': 114},
#  {'fields': {'url': 'https://www.hackerrank.com/challenges/most-commons',
#    'title': 'Company Logo',
#    'exbank': '해커랭크',
#    'cate1': '초급',
#    'cate2': '3단계',
#    'cate3': '문자열 이용',
#    'correct_ratio': 0.880709,
#    'pid': None,
#    'difficulty': 3},
#   'model': 'problem.problemex',
#   'pk': 115},
#  {'fields': {'url': 'https://www.hackerrank.com/challenges/standardize-mobile-number-using-decorators',
#    'title': 'Standardize Mobile Number Using Decorators',
#    'exbank': '해커랭크',
#    'cate1': '초급',
#    'cate2': '3단계',
#    'cate3': '문자열 이용',
#    'correct_ratio': 0.977487,
#    'pid': None,
#    'difficulty': 3},
#   'model': 'problem.problemex',
#   'pk': 116},
#  {'fields': {'url': 'https://www.hackerrank.com/challenges/words-score',
#    'title': 'Words Score',
#    'exbank': '해커랭크',
#    'cate1': '초급',
#    'cate2': '3단계',
#    'cate3': 'list',
#    'correct_ratio': 0.954291,
#    'pid': None,
#    'difficulty': 3},
#   'model': 'problem.problemex',
#   'pk': 117},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/1152',
#    'title': '단어의 개수',
#    'exbank': '백준',
#    'cate1': '초급',
#    'cate2': '3단계',
#    'cate3': 'list',
#    'correct_ratio': 0.2426,
#    'pid': 1152.0,
#    'difficulty': 3},
#   'model': 'problem.problemex',
#   'pk': 118},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/2577',
#    'title': '숫자의 개수',
#    'exbank': '백준',
#    'cate1': '초급',
#    'cate2': '3단계',
#    'cate3': 'list',
#    'correct_ratio': 0.6487,
#    'pid': 2577.0,
#    'difficulty': 3},
#   'model': 'problem.problemex',
#   'pk': 119},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/8958',
#    'title': 'OX퀴즈',
#    'exbank': '백준',
#    'cate1': '초급',
#    'cate2': '3단계',
#    'cate3': 'list',
#    'correct_ratio': 0.5626,
#    'pid': 8958.0,
#    'difficulty': 3},
#   'model': 'problem.problemex',
#   'pk': 120},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/2920',
#    'title': '음계',
#    'exbank': '백준',
#    'cate1': '초급',
#    'cate2': '3단계',
#    'cate3': 'list',
#    'correct_ratio': 0.5824,
#    'pid': 2920.0,
#    'difficulty': 3},
#   'model': 'problem.problemex',
#   'pk': 121},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/10039',
#    'title': '평균 점수',
#    'exbank': '백준',
#    'cate1': '초급',
#    'cate2': '3단계',
#    'cate3': 'list',
#    'correct_ratio': 0.7349,
#    'pid': 10039.0,
#    'difficulty': 3},
#   'model': 'problem.problemex',
#   'pk': 122},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/10809',
#    'title': '알파벳 찾기',
#    'exbank': '백준',
#    'cate1': '초급',
#    'cate2': '3단계',
#    'cate3': '문자열 이용',
#    'correct_ratio': 0.5668,
#    'pid': 10809.0,
#    'difficulty': 3},
#   'model': 'problem.problemex',
#   'pk': 123},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/2675',
#    'title': '문자열 반복',
#    'exbank': '백준',
#    'cate1': '초급',
#    'cate2': '3단계',
#    'cate3': '문자열 이용',
#    'correct_ratio': 0.5528,
#    'pid': 2675.0,
#    'difficulty': 3},
#   'model': 'problem.problemex',
#   'pk': 124},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/1157',
#    'title': '단어 공부',
#    'exbank': '백준',
#    'cate1': '초급',
#    'cate2': '3단계',
#    'cate3': '문자열 이용',
#    'correct_ratio': 0.3739,
#    'pid': 1157.0,
#    'difficulty': 3},
#   'model': 'problem.problemex',
#   'pk': 125},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/1316',
#    'title': '그룹 단어 체커',
#    'exbank': '백준',
#    'cate1': '초급',
#    'cate2': '3단계',
#    'cate3': '문자열 이용',
#    'correct_ratio': 0.519,
#    'pid': 1316.0,
#    'difficulty': 3},
#   'model': 'problem.problemex',
#   'pk': 126},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/2908',
#    'title': '상수',
#    'exbank': '백준',
#    'cate1': '초급',
#    'cate2': '3단계',
#    'cate3': '문자열 이용',
#    'correct_ratio': 0.6963,
#    'pid': 2908.0,
#    'difficulty': 3},
#   'model': 'problem.problemex',
#   'pk': 127},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/5622',
#    'title': '다이얼',
#    'exbank': '백준',
#    'cate1': '초급',
#    'cate2': '3단계',
#    'cate3': '문자열 이용',
#    'correct_ratio': 0.5807,
#    'pid': 5622.0,
#    'difficulty': 3},
#   'model': 'problem.problemex',
#   'pk': 128},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/2941',
#    'title': '크로아티아 알파벳',
#    'exbank': '백준',
#    'cate1': '초급',
#    'cate2': '3단계',
#    'cate3': '문자열 이용',
#    'correct_ratio': 0.4738,
#    'pid': 2941.0,
#    'difficulty': 3},
#   'model': 'problem.problemex',
#   'pk': 129},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/10219',
#    'title': 'Meats On The Grill',
#    'exbank': '백준',
#    'cate1': '초급',
#    'cate2': '3단계',
#    'cate3': 'list',
#    'correct_ratio': 0.6189,
#    'pid': 10219.0,
#    'difficulty': 3},
#   'model': 'problem.problemex',
#   'pk': 130},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/1547',
#    'title': '공',
#    'exbank': '백준',
#    'cate1': '초급',
#    'cate2': '3단계',
#    'cate3': 'list',
#    'correct_ratio': 0.7142,
#    'pid': 1547.0,
#    'difficulty': 3},
#   'model': 'problem.problemex',
#   'pk': 131},
#  {'fields': {'url': 'https://www.hackerrank.com/challenges/finding-the-percentage',
#    'title': 'Finding the percentage',
#    'exbank': '해커랭크',
#    'cate1': '중급',
#    'cate2': '1단계',
#    'cate3': 'dictionary',
#    'correct_ratio': 0.971267,
#    'pid': None,
#    'difficulty': 4},
#   'model': 'problem.problemex',
#   'pk': 132},
#  {'fields': {'url': 'https://www.hackerrank.com/challenges/string-validators',
#    'title': 'String Validators',
#    'exbank': '해커랭크',
#    'cate1': '중급',
#    'cate2': '1단계',
#    'cate3': '함수 사용',
#    'correct_ratio': 0.938186,
#    'pid': None,
#    'difficulty': 4},
#   'model': 'problem.problemex',
#   'pk': 133},
#  {'fields': {'url': 'https://www.hackerrank.com/challenges/py-set-add',
#    'title': 'Set .add()',
#    'exbank': '해커랭크',
#    'cate1': '중급',
#    'cate2': '1단계',
#    'cate3': 'set',
#    'correct_ratio': 0.992978,
#    'pid': None,
#    'difficulty': 4},
#   'model': 'problem.problemex',
#   'pk': 134},
#  {'fields': {'url': 'https://www.hackerrank.com/challenges/word-order',
#    'title': 'Word Order',
#    'exbank': '해커랭크',
#    'cate1': '중급',
#    'cate2': '1단계',
#    'cate3': 'dictionary',
#    'correct_ratio': 0.877751,
#    'pid': None,
#    'difficulty': 4},
#   'model': 'problem.problemex',
#   'pk': 135},
#  {'fields': {'url': 'https://www.hackerrank.com/challenges/py-set-discard-remove-pop',
#    'title': 'Set .discard(), .remove() & .pop()',
#    'exbank': '해커랭크',
#    'cate1': '중급',
#    'cate2': '1단계',
#    'cate3': 'set',
#    'correct_ratio': 0.968613,
#    'pid': None,
#    'difficulty': 4},
#   'model': 'problem.problemex',
#   'pk': 136},
#  {'fields': {'url': 'https://www.hackerrank.com/challenges/py-set-union',
#    'title': 'Set .union() Operation',
#    'exbank': '해커랭크',
#    'cate1': '중급',
#    'cate2': '1단계',
#    'cate3': 'set',
#    'correct_ratio': 0.993646,
#    'pid': None,
#    'difficulty': 4},
#   'model': 'problem.problemex',
#   'pk': 137},
#  {'fields': {'url': 'https://www.hackerrank.com/challenges/py-set-intersection-operation',
#    'title': 'Set .intersection() Operation',
#    'exbank': '해커랭크',
#    'cate1': '중급',
#    'cate2': '1단계',
#    'cate3': 'set',
#    'correct_ratio': 0.995489,
#    'pid': None,
#    'difficulty': 4},
#   'model': 'problem.problemex',
#   'pk': 138},
#  {'fields': {'url': 'https://www.hackerrank.com/challenges/python-power-mod-power',
#    'title': 'Power - Mod Power',
#    'exbank': '해커랭크',
#    'cate1': '중급',
#    'cate2': '1단계',
#    'cate3': '함수 사용',
#    'correct_ratio': 0.99256,
#    'pid': None,
#    'difficulty': 4},
#   'model': 'problem.problemex',
#   'pk': 139},
#  {'fields': {'url': 'https://www.hackerrank.com/challenges/py-set-difference-operation',
#    'title': 'Set .difference() Operation',
#    'exbank': '해커랭크',
#    'cate1': '중급',
#    'cate2': '1단계',
#    'cate3': 'set',
#    'correct_ratio': 0.994637,
#    'pid': None,
#    'difficulty': 4},
#   'model': 'problem.problemex',
#   'pk': 140},
#  {'fields': {'url': 'https://www.hackerrank.com/challenges/py-set-symmetric-difference-operation',
#    'title': 'Set .symmetric_difference() Operation',
#    'exbank': '해커랭크',
#    'cate1': '중급',
#    'cate2': '1단계',
#    'cate3': 'set',
#    'correct_ratio': 0.996552,
#    'pid': None,
#    'difficulty': 4},
#   'model': 'problem.problemex',
#   'pk': 141},
#  {'fields': {'url': 'https://www.hackerrank.com/challenges/py-set-mutations',
#    'title': 'Set Mutations',
#    'exbank': '해커랭크',
#    'cate1': '중급',
#    'cate2': '1단계',
#    'cate3': 'set',
#    'correct_ratio': 0.984463,
#    'pid': None,
#    'difficulty': 4},
#   'model': 'problem.problemex',
#   'pk': 142},
#  {'fields': {'url': 'https://www.hackerrank.com/challenges/py-the-captains-room',
#    'title': "The Captain's Room",
#    'exbank': '해커랭크',
#    'cate1': '중급',
#    'cate2': '1단계',
#    'cate3': 'set',
#    'correct_ratio': 0.904113,
#    'pid': None,
#    'difficulty': 4},
#   'model': 'problem.problemex',
#   'pk': 143},
#  {'fields': {'url': 'https://www.hackerrank.com/challenges/zipped',
#    'title': 'Zipped!',
#    'exbank': '해커랭크',
#    'cate1': '중급',
#    'cate2': '1단계',
#    'cate3': '함수 사용',
#    'correct_ratio': 0.97752,
#    'pid': None,
#    'difficulty': 4},
#   'model': 'problem.problemex',
#   'pk': 144},
#  {'fields': {'url': 'https://www.hackerrank.com/challenges/python-eval',
#    'title': 'Python Evaluation',
#    'exbank': '해커랭크',
#    'cate1': '중급',
#    'cate2': '1단계',
#    'cate3': '함수 사용',
#    'correct_ratio': 0.972603,
#    'pid': None,
#    'difficulty': 4},
#   'model': 'problem.problemex',
#   'pk': 145},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/1065',
#    'title': '한수',
#    'exbank': '백준',
#    'cate1': '중급',
#    'cate2': '1단계',
#    'cate3': '함수 사용',
#    'correct_ratio': 0.4553,
#    'pid': 1065.0,
#    'difficulty': 4},
#   'model': 'problem.problemex',
#   'pk': 146},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/11654',
#    'title': '아스키 코드',
#    'exbank': '백준',
#    'cate1': '중급',
#    'cate2': '1단계',
#    'cate3': '함수 사용',
#    'correct_ratio': 0.8309,
#    'pid': 11654.0,
#    'difficulty': 4},
#   'model': 'problem.problemex',
#   'pk': 147},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/1978',
#    'title': '소수 찾기',
#    'exbank': '백준',
#    'cate1': '중급',
#    'cate2': '1단계',
#    'cate3': '함수 사용',
#    'correct_ratio': 0.4919,
#    'pid': 1978.0,
#    'difficulty': 4},
#   'model': 'problem.problemex',
#   'pk': 148},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/2581',
#    'title': '소수',
#    'exbank': '백준',
#    'cate1': '중급',
#    'cate2': '1단계',
#    'cate3': '함수 사용',
#    'correct_ratio': 0.3763,
#    'pid': 2581.0,
#    'difficulty': 4},
#   'model': 'problem.problemex',
#   'pk': 149},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/2748',
#    'title': '피보나치 수 2',
#    'exbank': '백준',
#    'cate1': '중급',
#    'cate2': '1단계',
#    'cate3': '함수 사용',
#    'correct_ratio': 0.4165,
#    'pid': 2748.0,
#    'difficulty': 4},
#   'model': 'problem.problemex',
#   'pk': 150},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/11050',
#    'title': '이항 계수 1',
#    'exbank': '백준',
#    'cate1': '중급',
#    'cate2': '1단계',
#    'cate3': '함수 사용',
#    'correct_ratio': 0.6435,
#    'pid': 11050.0,
#    'difficulty': 4},
#   'model': 'problem.problemex',
#   'pk': 151},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/10872',
#    'title': '팩토리얼',
#    'exbank': '백준',
#    'cate1': '중급',
#    'cate2': '1단계',
#    'cate3': '함수 사용',
#    'correct_ratio': 0.6197,
#    'pid': 10872.0,
#    'difficulty': 4},
#   'model': 'problem.problemex',
#   'pk': 152},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/9375',
#    'title': '패션왕 신해빈',
#    'exbank': '백준',
#    'cate1': '중급',
#    'cate2': '1단계',
#    'cate3': 'dictionary',
#    'correct_ratio': 0.5306,
#    'pid': 9375.0,
#    'difficulty': 4},
#   'model': 'problem.problemex',
#   'pk': 153},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/1934',
#    'title': '최소공배수',
#    'exbank': '백준',
#    'cate1': '중급',
#    'cate2': '1단계',
#    'cate3': '함수 사용',
#    'correct_ratio': 0.588,
#    'pid': 1934.0,
#    'difficulty': 4},
#   'model': 'problem.problemex',
#   'pk': 154},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/13241',
#    'title': '최소공배수',
#    'exbank': '백준',
#    'cate1': '중급',
#    'cate2': '1단계',
#    'cate3': '함수 사용',
#    'correct_ratio': 0.6309,
#    'pid': 13241.0,
#    'difficulty': 4},
#   'model': 'problem.problemex',
#   'pk': 155},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/2609',
#    'title': '최대공약수와 최소공배수',
#    'exbank': '백준',
#    'cate1': '중급',
#    'cate2': '1단계',
#    'cate3': '함수 사용',
#    'correct_ratio': 0.6649,
#    'pid': 2609.0,
#    'difficulty': 4},
#   'model': 'problem.problemex',
#   'pk': 156},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/1850',
#    'title': '최대공약수',
#    'exbank': '백준',
#    'cate1': '중급',
#    'cate2': '1단계',
#    'cate3': '함수 사용',
#    'correct_ratio': 0.277,
#    'pid': 1850.0,
#    'difficulty': 4},
#   'model': 'problem.problemex',
#   'pk': 157},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/3036',
#    'title': '링',
#    'exbank': '백준',
#    'cate1': '중급',
#    'cate2': '1단계',
#    'cate3': '함수 사용',
#    'correct_ratio': 0.8208,
#    'pid': 3036.0,
#    'difficulty': 4},
#   'model': 'problem.problemex',
#   'pk': 158},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/10253',
#    'title': '헨리',
#    'exbank': '백준',
#    'cate1': '중급',
#    'cate2': '1단계',
#    'cate3': '함수 사용',
#    'correct_ratio': 0.2855,
#    'pid': 10253.0,
#    'difficulty': 4},
#   'model': 'problem.problemex',
#   'pk': 159},
#  {'fields': {'url': 'https://www.hackerrank.com/challenges/designer-door-mat',
#    'title': 'Designer Door Mat',
#    'exbank': '해커랭크',
#    'cate1': '고급',
#    'cate2': '2단계',
#    'cate3': '기타',
#    'correct_ratio': 0.982432,
#    'pid': None,
#    'difficulty': 8},
#   'model': 'problem.problemex',
#   'pk': 160},
#  {'fields': {'url': 'https://www.hackerrank.com/challenges/python-string-formatting',
#    'title': 'String Formatting',
#    'exbank': '해커랭크',
#    'cate1': '고급',
#    'cate2': '2단계',
#    'cate3': '기타',
#    'correct_ratio': 0.915458,
#    'pid': None,
#    'difficulty': 8},
#   'model': 'problem.problemex',
#   'pk': 161},
#  {'fields': {'url': 'https://www.hackerrank.com/challenges/python-sort-sort',
#    'title': 'Athlete Sort',
#    'exbank': '해커랭크',
#    'cate1': '고급',
#    'cate2': '2단계',
#    'cate3': '기타',
#    'correct_ratio': 0.961567,
#    'pid': None,
#    'difficulty': 8},
#   'model': 'problem.problemex',
#   'pk': 162},
#  {'fields': {'url': 'https://www.hackerrank.com/challenges/introduction-to-regex',
#    'title': 'Detect Floating Point Number',
#    'exbank': '해커랭크',
#    'cate1': '고급',
#    'cate2': '2단계',
#    'cate3': '정규표현식',
#    'correct_ratio': 0.917035,
#    'pid': None,
#    'difficulty': 8},
#   'model': 'problem.problemex',
#   'pk': 163},
#  {'fields': {'url': 'https://www.hackerrank.com/challenges/re-split',
#    'title': 'Re.split()',
#    'exbank': '해커랭크',
#    'cate1': '고급',
#    'cate2': '2단계',
#    'cate3': '정규표현식',
#    'correct_ratio': 0.939759,
#    'pid': None,
#    'difficulty': 8},
#   'model': 'problem.problemex',
#   'pk': 164},
#  {'fields': {'url': 'https://www.hackerrank.com/challenges/validate-list-of-email-address-with-filter',
#    'title': 'Validating Email Addresses With a Filter',
#    'exbank': '해커랭크',
#    'cate1': '고급',
#    'cate2': '2단계',
#    'cate3': '정규표현식',
#    'correct_ratio': 0.880835,
#    'pid': None,
#    'difficulty': 8},
#   'model': 'problem.problemex',
#   'pk': 165},
#  {'fields': {'url': 'https://www.hackerrank.com/challenges/re-group-groups',
#    'title': 'Group(), Groups() & Groupdict()',
#    'exbank': '해커랭크',
#    'cate1': '고급',
#    'cate2': '2단계',
#    'cate3': '정규표현식',
#    'correct_ratio': 0.926869,
#    'pid': None,
#    'difficulty': 8},
#   'model': 'problem.problemex',
#   'pk': 166},
#  {'fields': {'url': 'https://www.hackerrank.com/challenges/re-findall-re-finditer',
#    'title': 'Re.findall() & Re.finditer()',
#    'exbank': '해커랭크',
#    'cate1': '고급',
#    'cate2': '2단계',
#    'cate3': '정규표현식',
#    'correct_ratio': 0.889458,
#    'pid': None,
#    'difficulty': 8},
#   'model': 'problem.problemex',
#   'pk': 167},
# ...
#    'difficulty': 8},
#   'model': 'problem.problemex',
#   'pk': 215},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/1931',
#    'title': '회의실배정',
#    'exbank': '백준',
#    'cate1': '고급',
#    'cate2': '2단계',
#    'cate3': 'greedy algorithm',
#    'correct_ratio': 0.2946,
#    'pid': 1931.0,
#    'difficulty': 8},
#   'model': 'problem.problemex',
#   'pk': 216},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/11047',
#    'title': '동전 0',
#    'exbank': '백준',
#    'cate1': '고급',
#    'cate2': '2단계',
#    'cate3': 'greedy algorithm',
#    'correct_ratio': 0.5853,
#    'pid': 11047.0,
#    'difficulty': 8},
#   'model': 'problem.problemex',
#   'pk': 217},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/11399',
#    'title': 'ATM',
#    'exbank': '백준',
#    'cate1': '고급',
#    'cate2': '2단계',
#    'cate3': 'greedy algorithm',
#    'correct_ratio': 0.7068,
#    'pid': 11399.0,
#    'difficulty': 8},
#   'model': 'problem.problemex',
#   'pk': 218},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/2217',
#    'title': '로프',
#    'exbank': '백준',
#    'cate1': '고급',
#    'cate2': '2단계',
#    'cate3': 'greedy algorithm',
#    'correct_ratio': 0.4754,
#    'pid': 2217.0,
#    'difficulty': 8},
#   'model': 'problem.problemex',
#   'pk': 219},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/4307',
#    'title': '개미',
#    'exbank': '백준',
#    'cate1': '고급',
#    'cate2': '2단계',
#    'cate3': 'greedy algorithm',
#    'correct_ratio': 0.481,
#    'pid': 4307.0,
#    'difficulty': 8},
#   'model': 'problem.problemex',
#   'pk': 220},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/9663',
#    'title': 'N-Queen',
#    'exbank': '백준',
#    'cate1': '고급',
#    'cate2': '2단계',
#    'cate3': 'backtracking',
#    'correct_ratio': 0.5724,
#    'pid': 9663.0,
#    'difficulty': 8},
#   'model': 'problem.problemex',
#   'pk': 221},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/2580',
#    'title': '스도쿠',
#    'exbank': '백준',
#    'cate1': '고급',
#    'cate2': '2단계',
#    'cate3': 'backtracking',
#    'correct_ratio': 0.3252,
#    'pid': 2580.0,
#    'difficulty': 8},
#   'model': 'problem.problemex',
#   'pk': 222},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/2661',
#    'title': '좋은수열',
#    'exbank': '백준',
#    'cate1': '고급',
#    'cate2': '2단계',
#    'cate3': 'backtracking',
#    'correct_ratio': 0.5628,
#    'pid': 2661.0,
#    'difficulty': 8},
#   'model': 'problem.problemex',
#   'pk': 223},
#  {'fields': {'url': 'https://www.hackerrank.com/challenges/exceptions',
#    'title': 'Exceptions',
#    'exbank': '해커랭크',
#    'cate1': '고급',
#    'cate2': '1단계',
#    'cate3': '예외 처리',
#    'correct_ratio': 0.963788,
#    'pid': None,
#    'difficulty': 7},
#   'model': 'problem.problemex',
#   'pk': 224},
#  {'fields': {'url': 'https://www.hackerrank.com/challenges/incorrect-regex',
#    'title': 'Incorrect Regex',
#    'exbank': '해커랭크',
#    'cate1': '고급',
#    'cate2': '1단계',
#    'cate3': '예외 처리',
#    'correct_ratio': 0.979607,
#    'pid': None,
#    'difficulty': 7},
#   'model': 'problem.problemex',
#   'pk': 225},
#  {'fields': {'url': 'https://www.hackerrank.com/challenges/class-1-dealing-with-complex-numbers',
#    'title': 'Classes: Dealing with Complex Numbers',
#    'exbank': '해커랭크',
#    'cate1': '고급',
#    'cate2': '1단계',
#    'cate3': '객체 지향적 사고',
#    'correct_ratio': 0.912321,
#    'pid': None,
#    'difficulty': 7},
#   'model': 'problem.problemex',
#   'pk': 226},
#  {'fields': {'url': 'https://www.hackerrank.com/challenges/class-2-find-the-torsional-angle',
#    'title': 'Class 2 - Find the Torsional Angle',
#    'exbank': '해커랭크',
#    'cate1': '고급',
#    'cate2': '1단계',
#    'cate3': '객체 지향적 사고',
#    'correct_ratio': 0.972841,
#    'pid': None,
#    'difficulty': 7},
#   'model': 'problem.problemex',
#   'pk': 227},
#  {'fields': {'url': 'https://www.hackerrank.com/challenges/default-arguments',
#    'title': 'Default Arguments',
#    'exbank': '해커랭크',
#    'cate1': '고급',
#    'cate2': '1단계',
#    'cate3': '객체 지향적 사고',
#    'correct_ratio': 0.80641,
#    'pid': None,
#    'difficulty': 7},
#   'model': 'problem.problemex',
#   'pk': 228},
#  {'fields': {'url': 'https://www.hackerrank.com/challenges/ginorts',
#    'title': 'ginortS',
#    'exbank': '해커랭크',
#    'cate1': '중급',
#    'cate2': '3단계',
#    'cate3': 'Sorting',
#    'correct_ratio': 0.964414,
#    'pid': None,
#    'difficulty': 6},
#   'model': 'problem.problemex',
#   'pk': 229},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/2750',
#    'title': '수 정렬하기',
#    'exbank': '백준',
#    'cate1': '중급',
#    'cate2': '3단계',
#    'cate3': 'Sorting',
#    'correct_ratio': 0.5857,
#    'pid': 2750.0,
#    'difficulty': 6},
#   'model': 'problem.problemex',
#   'pk': 230},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/2751',
#    'title': '수 정렬하기 2',
#    'exbank': '백준',
#    'cate1': '중급',
#    'cate2': '3단계',
#    'cate3': 'Sorting',
#    'correct_ratio': 0.3276,
#    'pid': 2751.0,
#    'difficulty': 6},
#   'model': 'problem.problemex',
#   'pk': 231},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/10989',
#    'title': '수 정렬하기 3',
#    'exbank': '백준',
#    'cate1': '중급',
#    'cate2': '3단계',
#    'cate3': 'Sorting',
#    'correct_ratio': 0.2334,
#    'pid': 10989.0,
#    'difficulty': 6},
#   'model': 'problem.problemex',
#   'pk': 232},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/2108',
#    'title': '통계학',
#    'exbank': '백준',
#    'cate1': '중급',
#    'cate2': '3단계',
#    'cate3': 'Sorting',
#    'correct_ratio': 0.2699,
#    'pid': 2108.0,
#    'difficulty': 6},
#   'model': 'problem.problemex',
#   'pk': 233},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/1427',
#    'title': '소트인사이드',
#    'exbank': '백준',
#    'cate1': '중급',
#    'cate2': '3단계',
#    'cate3': 'Sorting',
#    'correct_ratio': 0.5999,
#    'pid': 1427.0,
#    'difficulty': 6},
#   'model': 'problem.problemex',
#   'pk': 234},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/1181',
#    'title': '단어 정렬',
#    'exbank': '백준',
#    'cate1': '중급',
#    'cate2': '3단계',
#    'cate3': 'Sorting',
#    'correct_ratio': 0.3727,
#    'pid': 1181.0,
#    'difficulty': 6},
#   'model': 'problem.problemex',
#   'pk': 235},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/1920',
#    'title': '수 찾기',
#    'exbank': '백준',
#    'cate1': '중급',
#    'cate2': '3단계',
#    'cate3': 'Searching',
#    'correct_ratio': 0.2754,
#    'pid': 1920.0,
#    'difficulty': 6},
#   'model': 'problem.problemex',
#   'pk': 236},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/1654',
#    'title': '랜선 자르기',
#    'exbank': '백준',
#    'cate1': '중급',
#    'cate2': '3단계',
#    'cate3': 'Searching',
#    'correct_ratio': 0.1867,
#    'pid': 1654.0,
#    'difficulty': 6},
#   'model': 'problem.problemex',
#   'pk': 237},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/10815',
#    'title': '숫자 카드',
#    'exbank': '백준',
#    'cate1': '중급',
#    'cate2': '3단계',
#    'cate3': 'Searching',
#    'correct_ratio': 0.4702,
#    'pid': 10815.0,
#    'difficulty': 6},
#   'model': 'problem.problemex',
#   'pk': 238},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/1300',
#    'title': 'K째 수',
#    'exbank': '백준',
#    'cate1': '중급',
#    'cate2': '3단계',
#    'cate3': 'Searching',
#    'correct_ratio': 0.364,
#    'pid': 1300.0,
#    'difficulty': 6},
#   'model': 'problem.problemex',
#   'pk': 239},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/1003',
#    'title': '피보나치 함수',
#    'exbank': '백준',
#    'cate1': '고급',
#    'cate2': '3단계',
#    'cate3': '동적 프로그래밍',
#    'correct_ratio': 0.2913,
#    'pid': 1003.0,
#    'difficulty': 9},
#   'model': 'problem.problemex',
#   'pk': 240},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/11051',
#    'title': '이항 계수 2',
#    'exbank': '백준',
#    'cate1': '고급',
#    'cate2': '3단계',
#    'cate3': '동적 프로그래밍',
#    'correct_ratio': 0.3837,
#    'pid': 11051.0,
#    'difficulty': 9},
#   'model': 'problem.problemex',
#   'pk': 241},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/2407',
#    'title': '조합',
#    'exbank': '백준',
#    'cate1': '고급',
#    'cate2': '3단계',
#    'cate3': '동적 프로그래밍',
#    'correct_ratio': 0.3264,
#    'pid': 2407.0,
#    'difficulty': 9},
#   'model': 'problem.problemex',
#   'pk': 242},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/1149',
#    'title': 'RGB거리',
#    'exbank': '백준',
#    'cate1': '고급',
#    'cate2': '3단계',
#    'cate3': '동적 프로그래밍',
#    'correct_ratio': 0.4646,
#    'pid': 1149.0,
#    'difficulty': 9},
#   'model': 'problem.problemex',
#   'pk': 243},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/1932',
#    'title': '정수 삼각형',
#    'exbank': '백준',
#    'cate1': '고급',
#    'cate2': '3단계',
#    'cate3': '동적 프로그래밍',
#    'correct_ratio': 0.5777,
#    'pid': 1932.0,
#    'difficulty': 9},
#   'model': 'problem.problemex',
#   'pk': 244},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/2579',
#    'title': '계단 오르기',
#    'exbank': '백준',
#    'cate1': '고급',
#    'cate2': '3단계',
#    'cate3': '동적 프로그래밍',
#    'correct_ratio': 0.3892,
#    'pid': 2579.0,
#    'difficulty': 9},
#   'model': 'problem.problemex',
#   'pk': 245},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/1463',
#    'title': '1로 만들기',
#    'exbank': '백준',
#    'cate1': '고급',
#    'cate2': '3단계',
#    'cate3': '동적 프로그래밍',
#    'correct_ratio': 0.3206,
#    'pid': 1463.0,
#    'difficulty': 9},
#   'model': 'problem.problemex',
#   'pk': 246},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/1005',
#    'title': 'ACM Craft',
#    'exbank': '백준',
#    'cate1': '고급',
#    'cate2': '3단계',
#    'cate3': '동적 프로그래밍',
#    'correct_ratio': 0.182,
#    'pid': 1005.0,
#    'difficulty': 9},
#   'model': 'problem.problemex',
#   'pk': 247},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/10844',
#    'title': '쉬운 계단 수',
#    'exbank': '백준',
#    'cate1': '고급',
#    'cate2': '3단계',
#    'cate3': '동적 프로그래밍',
#    'correct_ratio': 0.2846,
#    'pid': 10844.0,
#    'difficulty': 9},
#   'model': 'problem.problemex',
#   'pk': 248},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/2293',
#    'title': '동전 1',
#    'exbank': '백준',
#    'cate1': '고급',
#    'cate2': '3단계',
#    'cate3': '동적 프로그래밍',
#    'correct_ratio': 0.4157,
#    'pid': 2293.0,
#    'difficulty': 9},
#   'model': 'problem.problemex',
#   'pk': 249},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/2156',
#    'title': '포도주 시식',
#    'exbank': '백준',
#    'cate1': '고급',
#    'cate2': '3단계',
#    'cate3': '동적 프로그래밍',
#    'correct_ratio': 0.3438,
#    'pid': 2156.0,
#    'difficulty': 9},
#   'model': 'problem.problemex',
#   'pk': 250},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/1520',
#    'title': '내리막 길',
#    'exbank': '백준',
#    'cate1': '고급',
#    'cate2': '3단계',
#    'cate3': '동적 프로그래밍',
#    'correct_ratio': 0.2671,
#    'pid': 1520.0,
#    'difficulty': 9},
#   'model': 'problem.problemex',
#   'pk': 251},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/9251',
#    'title': 'LCS',
#    'exbank': '백준',
#    'cate1': '고급',
#    'cate2': '3단계',
#    'cate3': '동적 프로그래밍',
#    'correct_ratio': 0.4197,
#    'pid': 9251.0,
#    'difficulty': 9},
#   'model': 'problem.problemex',
#   'pk': 252},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/11066',
#    'title': '파일 합치기',
#    'exbank': '백준',
#    'cate1': '고급',
#    'cate2': '3단계',
#    'cate3': '동적 프로그래밍',
#    'correct_ratio': 0.5207,
#    'pid': 11066.0,
#    'difficulty': 9},
#   'model': 'problem.problemex',
#   'pk': 253},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/1912',
#    'title': '연속합',
#    'exbank': '백준',
#    'cate1': '고급',
#    'cate2': '3단계',
#    'cate3': '동적 프로그래밍',
#    'correct_ratio': 0.27,
#    'pid': 1912.0,
#    'difficulty': 9},
#   'model': 'problem.problemex',
#   'pk': 254},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/9461',
#    'title': '파도반 수열',
#    'exbank': '백준',
#    'cate1': '고급',
#    'cate2': '3단계',
#    'cate3': '동적 프로그래밍',
#    'correct_ratio': 0.3832,
#    'pid': 9461.0,
#    'difficulty': 9},
#   'model': 'problem.problemex',
#   'pk': 255},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/9252',
#    'title': 'LCS 2',
#    'exbank': '백준',
#    'cate1': '고급',
#    'cate2': '3단계',
#    'cate3': '동적 프로그래밍',
#    'correct_ratio': 0.4169,
#    'pid': 9252.0,
#    'difficulty': 9},
#   'model': 'problem.problemex',
#   'pk': 256},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/1693',
#    'title': '트리 색칠하기',
#    'exbank': '백준',
#    'cate1': '고급',
#    'cate2': '3단계',
#    'cate3': '동적 프로그래밍',
#    'correct_ratio': 0.2495,
#    'pid': 1693.0,
#    'difficulty': 9},
#   'model': 'problem.problemex',
#   'pk': 257},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/2098',
#    'title': '외판원 순회',
#    'exbank': '백준',
#    'cate1': '고급',
#    'cate2': '3단계',
#    'cate3': '동적 프로그래밍',
#    'correct_ratio': 0.2605,
#    'pid': 2098.0,
#    'difficulty': 9},
#   'model': 'problem.problemex',
#   'pk': 258},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/2618',
#    'title': '경찰차',
#    'exbank': '백준',
#    'cate1': '고급',
#    'cate2': '3단계',
#    'cate3': '동적 프로그래밍',
#    'correct_ratio': 0.2919,
#    'pid': 2618.0,
#    'difficulty': 9},
#   'model': 'problem.problemex',
#   'pk': 259},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/1315',
#    'title': 'RPG',
#    'exbank': '백준',
#    'cate1': '고급',
#    'cate2': '3단계',
#    'cate3': '동적 프로그래밍',
#    'correct_ratio': 0.1908,
#    'pid': 1315.0,
#    'difficulty': 9},
#   'model': 'problem.problemex',
#   'pk': 260},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/11062',
#    'title': '카드 게임',
#    'exbank': '백준',
#    'cate1': '고급',
#    'cate2': '3단계',
#    'cate3': '동적 프로그래밍',
#    'correct_ratio': 0.4369,
#    'pid': 11062.0,
#    'difficulty': 9},
#   'model': 'problem.problemex',
#   'pk': 261},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/1562',
#    'title': '계단 수',
#    'exbank': '백준',
#    'cate1': '고급',
#    'cate2': '3단계',
#    'cate3': '동적 프로그래밍',
#    'correct_ratio': 0.4527,
#    'pid': 1562.0,
#    'difficulty': 9},
#   'model': 'problem.problemex',
#   'pk': 262},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/2342',
#    'title': 'Dance Dance Revolution',
#    'exbank': '백준',
#    'cate1': '고급',
#    'cate2': '3단계',
#    'cate3': '동적 프로그래밍',
#    'correct_ratio': 0.3286,
#    'pid': 2342.0,
#    'difficulty': 9},
#   'model': 'problem.problemex',
#   'pk': 263},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/2449',
#    'title': '전구',
#    'exbank': '백준',
#    'cate1': '고급',
#    'cate2': '3단계',
#    'cate3': '동적 프로그래밍',
#    'correct_ratio': 0.4056,
#    'pid': 2449.0,
#    'difficulty': 9},
#   'model': 'problem.problemex',
#   'pk': 264},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/10272',
#    'title': '현상금 사냥꾼 김정은',
#    'exbank': '백준',
#    'cate1': '고급',
#    'cate2': '3단계',
#    'cate3': '동적 프로그래밍',
#    'correct_ratio': 0.4368,
#    'pid': 10272.0,
#    'difficulty': 9},
#   'model': 'problem.problemex',
#   'pk': 265},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/1958',
#    'title': 'LCS 3',
#    'exbank': '백준',
#    'cate1': '고급',
#    'cate2': '3단계',
#    'cate3': '동적 프로그래밍',
#    'correct_ratio': 0.4891,
#    'pid': 1958.0,
#    'difficulty': 9},
#   'model': 'problem.problemex',
#   'pk': 266},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/4243',
#    'title': '보안 업체',
#    'exbank': '백준',
#    'cate1': '고급',
#    'cate2': '3단계',
#    'cate3': '동적 프로그래밍',
#    'correct_ratio': 0.3029,
#    'pid': 4243.0,
#    'difficulty': 9},
#   'model': 'problem.problemex',
#   'pk': 267},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/1344',
#    'title': '축구',
#    'exbank': '백준',
#    'cate1': '고급',
#    'cate2': '3단계',
#    'cate3': '동적 프로그래밍',
#    'correct_ratio': 0.5639,
#    'pid': 1344.0,
#    'difficulty': 9},
#   'model': 'problem.problemex',
#   'pk': 268},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/13250',
#    'title': '주사위 게임',
#    'exbank': '백준',
#    'cate1': '고급',
#    'cate2': '3단계',
#    'cate3': '동적 프로그래밍',
#    'correct_ratio': 0.7061,
#    'pid': 13250.0,
#    'difficulty': 9},
#   'model': 'problem.problemex',
#   'pk': 269},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/2066',
#    'title': '카드놀이',
#    'exbank': '백준',
#    'cate1': '고급',
#    'cate2': '3단계',
#    'cate3': '동적 프로그래밍',
#    'correct_ratio': 0.4383,
#    'pid': 2066.0,
#    'difficulty': 9},
#   'model': 'problem.problemex',
#   'pk': 270},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/3946',
#    'title': '랜덤 걷기',
#    'exbank': '백준',
#    'cate1': '고급',
#    'cate2': '3단계',
#    'cate3': '동적 프로그래밍',
#    'correct_ratio': 0.4615,
#    'pid': 3946.0,
#    'difficulty': 9},
#   'model': 'problem.problemex',
#   'pk': 271},
#  {'fields': {'url': 'https://www.acmicpc.net/problem/1413',
#    'title': '박스 안의 열쇠',
#    'exbank': '백준',
#    'cate1': '고급',
#    'cate2': '3단계',
#    'cate3': '동적 프로그래밍',
#    'correct_ratio': 0.3763,
#    'pid': 1413.0,
#    'difficulty': 9},
#   'model': 'problem.problemex',
#   'pk': 272}]

# %%
str(hacker_json)
# Out:
# '[{\'fields\': {\'url\': \'https://www.hackerrank.com/challenges/py-hello-world\', \'title\': \'Say "Hello, World!" With Python\', \'exbank\': \'해커랭크\'}, \'model\': \'problem.problemex\', \'pk\': 3}, {\'fields\': {\'url\': \'https://www.hackerrank.com/challenges/py-if-else\', \'title\': \'Python If-Else\', \'exbank\': \'해커랭크\'}, \'model\': \'problem.problemex\', \'pk\': 4}, {\'fields\': {\'url\': \'https://www.hackerrank.com/challenges/python-arithmetic-operators\', \'title\': \'Arithmetic Operators\', \'exbank\': \'해커랭크\'}, \'model\': \'problem.problemex\', \'pk\': 5}, {\'fields\': {\'url\': \'https://www.hackerrank.com/challenges/python-division\', \'title\': \'Python: Division\', \'exbank\': \'해커랭크\'}, \'model\': \'problem.problemex\', \'pk\': 6}, {\'fields\': {\'url\': \'https://www.hackerrank.com/challenges/python-loops\', \'title\': \'Loops\', \'exbank\': \'해커랭크\'}, \'model\': \'problem.problemex\', \'pk\': 7}, {\'fields\': {\'url\': \'https://www.hackerrank.com/challenges/write-a-function\', \'title\': \'Write a function\', \'exbank\': \'해커랭크\'}, \'model\': \'problem.problemex\', \'pk\': 8}, {\'fields\': {\'url\': \'https://www.hackerrank.com/challenges/python-print\', \'title\': \'Print Function\', \'exbank\': \'해커랭크\'}, \'model\': \'problem.problemex\', \'pk\': 9}, {\'fields\': {\'url\': \'https://www.hackerrank.com/challenges/list-comprehensions\', \'title\': \'List Comprehensions\', \'exbank\': \'해커랭크\'}, \'model\': \'problem.problemex\', \'pk\': 10}, {\'fields\': {\'url\': \'https://www.hackerrank.com/challenges/find-second-maximum-number-in-a-list\', \'title\': \'Find the Runner-Up Score!\', \'exbank\': \'해커랭크\'}, \'model\': \'problem.problemex\', \'pk\': 11}, {\'fields\': {\'url\': \'https://www.hackerrank.com/challenges/nested-list\', \'title\': \'Nested Lists\', \'exbank\': \'해커랭크\'}, \'model\': \'problem.problemex\', \'pk\': 12}, {\'fields\': {\'url\': \'https://www.hackerrank.com/challenges/finding-the-percentage\', \'title\': \'Finding the percentage\', \'exbank\': \'해커랭크\'}, \'model\': \'problem.problemex\', \'pk\': 13}, {\'fields\': {\'url\': \'https://www.hackerrank.com/challenges/python-lists\', \'title\': \'Lists\', \'exbank\': \'해커랭크\'}, \'model\': \'problem.problemex\', \'pk\': 14}, {\'fields\': {\'url\': \'https://www.hackerrank.com/challenges/python-tuples\', \'title\': \'Tuples\', \'exbank\': \'해커랭크\'}, \'model\': \'problem.problemex\', \'pk\': 15}, {\'fields\': {\'url\': \'https://www.hackerrank.com/challenges/swap-case\', \'title\': \'sWAP cASE\', \'exbank\': \'해커랭크\'}, \'model\': \'problem.problemex\', \'pk\': 16}, {\'fields\': {\'url\': \'https://www.hackerrank.com/challenges/python-string-split-and-join\', \'title\': \'String Split and Join\', \'exbank\': \'해커랭크\'}, \'model\': \'problem.problemex\', \'pk\': 17}, {\'fields\': {\'url\': \'https://www.hackerrank.com/challenges/whats-your-name\', \'title\': "What\'s Your Name?", \'exbank\': \'해커랭크\'}, \'model\': \'problem.problemex\', \'pk\': 18}, {\'fields\': {\'url\': \'https://www.hackerrank.com/challenges/python-mutations\', \'title\': \'Mutations\', \'exbank\': \'해커랭크\'}, \'model\': \'problem.problemex\', \'pk\': 19}, {\'fields\': {\'url\': \'https://www.hackerrank.com/challenges/find-a-string\', \'title\': \'Find a string\', \'exbank\': \'해커랭크\'}, \'model\': \'problem.problemex\', \'pk\': 20}, {\'fields\': {\'url\': \'https://www.hackerrank.com/challenges/string-validators\', \'title\': \'String Validators\', \'exbank\': \'해커랭크\'}, \'model\': \'problem.problemex\', \'pk\': 21}, {\'fields\': {\'url\': \'https://www.hackerrank.com/challenges/text-alignment\', \'title\': \'Text Alignment\', \'exbank\': \'해커랭크\'}, \'model\': \'problem.problemex\', \'pk\': 22}, {\'fields\': {\'url\': \'https://www.hackerrank.com/challenges/text-wrap\', \'title\': \'Text Wrap\', \'exbank\': \'해커랭크\'}, \'model\': \'problem.problemex\', \'pk\': 23}, {\'fields\': {\'url\': \'https://www.hackerrank.com/challenges/designer-door-mat\', \'title\': \'Designer Door Mat\',  ...

# %%
'model': 'problem.problemex',
  'pk': 2,
  'fields': {'title': '테스트용도',
   'url': 'https://www.acmicpc.net/problem/10171',
   'exbank': '백준',
   'pid': 10171,
   'difficulty': 1,
   'cate1'
